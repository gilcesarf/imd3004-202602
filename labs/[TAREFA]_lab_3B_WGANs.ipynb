# %% [markdown]
# Código adaptado de:
#
# [1] D. Foster, Generative Deep Learning: Teaching Machines to Paint, Write, Compose, and Play, Second Edition, O'Reilly, 2023.
#
# [2] A. K. Nain, WGAN-GP overriding, disponível no site do Keras [(link)](https://keras.io/examples/generative/wgan_gp/).

# %% [markdown]
# # Laboratório 3B: WGAN condicional

# %% [markdown]
# ## Instalar bibliotecas necessárias

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)

# %% [markdown]
# ## Importações

# %%
import torch                                # Importa a biblioteca principal do PyTorch, usada para computação com tensores
from torch import nn                        # Importa o módulo 'nn' do PyTorch, utilizado para criar e treinar redes neurais
from torch.utils.data import DataLoader     # Importa o DataLoader do PyTorch, que facilita o carregamento de dados em mini-lotes (batches).
import torch.nn.functional as F             # Importa funções comuns de ativação e perda do PyTorch, usadas fora do módulo nn.Module (ex.: ReLU, cross_entropy, etc.)
from torchvision import datasets            # Importa o módulo de conjuntos de dados do torchvision, que fornece acesso a conjuntos de dados populares como MNIST, CIFAR, etc. para visão computacional
from torchvision import transforms          # Importa o módulo de transforms do torchvision, usado para pré-processar imagens (conversão em tensor, normalização, etc.).
from torchinfo import summary               # Importa a função summary da biblioteca torchinfo, usada para exibir a arquitetura do modelo
import numpy as np                          # Importa a biblioteca NumPy, usada para operações numéricas eficientes com arrays e matrizes.
import matplotlib.pyplot as plt             # Importa o módulo de visualização matplotlib para gerar gráficos.
from IPython.display import Image           # Importa a classe Image do IPython, usada para exibir imagens diretamente dentro de notebooks.
import os                                   # Importa o módulo padrão do Python para interagir com o sistema operacional (ex.: criar pastas, manipular caminhos de arquivos).
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE" # Ajusta a variável de ambiente para evitar erros ao carregar múltiplas bibliotecas MKL

# %%
# Para figuras geradas pelo matplotlib serem exibidas diretamente no notebook
# %matplotlib inline

# %% [markdown]
# ## Baixar e carregar os dados

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x * 2.0 - 1.0),
])

# Baixa os dados de treinamento a partir de conjuntos de dados públicos
training_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=True,              # Indica que este é o conjunto de dados de treinamento
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# Baixa os dados de teste a partir de conjuntos de dados públicos
test_data = datasets.FashionMNIST(
    root="data",             # Diretório onde os dados serão armazenados
    train=False,             # Indica que este é o conjunto de dados de teste
    download=True,           # Baixa os dados automaticamente, caso ainda não estejam presentes
    transform=transform,     # Aplica a transformação ToTensor para converter as imagens em tensores
)

# %%
# Lista com os nomes das classes do conjunto de dados Fashion MNIST, na mesma ordem dos índices
classes = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# Dicionário para armazenar um exemplo por classe
examples = {}

# Itera sobre o dataset até obter um exemplo de cada classe
for img, label in training_data:
    if label not in examples:
        examples[label] = img.squeeze()  # remove o canal extra (1, 28, 28) -> (28, 28)
    if len(examples) == 10:
        break

# Plota os exemplos
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(examples[i], cmap="gray")
    plt.title(classes[i])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
batch_size = 64                                                                                     # Define o tamanho do lote
train_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True, drop_last=True)   # Cria o DataLoader para o conjunto de treinamento
test_dataloader = DataLoader(test_data, batch_size=batch_size)                                      # Cria o DataLoader para o conjunto de teste

# Itera sobre o DataLoader de teste para visualizar as formas dos dados
for X, y in test_dataloader:
    # Exibe a forma e o tipo do tensor de imagens
    # N = tamanho do lote, C = canais (1 para imagens em tons de cinza), H = altura, W = largura
    print(f"Forma de X [N, C, H, W]: {X.shape}, Tipo de dados em X: {X.dtype}")

    # Exibe a forma e o tipo dos rótulos (labels)
    print(f"Forma de y [N, ] : {y.shape}, Tipo de dados em y: {y.dtype}")

    break  # Encerra o loop após a primeira iteração, apenas para inspeção dos dados
# Out:
# Forma de X [N, C, H, W]: torch.Size([64, 1, 28, 28]), Tipo de dados em X: torch.float32
# Forma de y [N, ] : torch.Size([64]), Tipo de dados em y: torch.int64

# %% [markdown]
# ## Redes Neurais

# %% [markdown]
# ### Gerador

# %%
class Gerador(nn.Module):

    def __init__(self, z_dim=100):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(z_dim, 7*7*128),
            nn.Unflatten(dim=1, unflattened_size=(128, 7, 7)),
            nn.BatchNorm2d(128),
            nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.ReLU(True),
            nn.BatchNorm2d(64),
            nn.ConvTranspose2d(64, 1, kernel_size=5, stride=2, padding=2, output_padding=1),
            nn.Tanh()
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ### Crítico

# %%
class Critico(nn.Module):

    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(p=0.4),
            nn.Conv2d(64, 128, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(negative_slope=0.2),
            nn.Dropout(p=0.4),
            nn.Flatten(),
            nn.Linear(7*7*128, 1),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## Treinamento

# %%
def train_wgan(dataloader, gerador, critico, opt_gerador, opt_critico, device, epoch, z_dim, n_critic=5, clip_value=0.01):
    gerador.train()
    critico.train()

    for batch, (real_data, _) in enumerate(dataloader):
        batch_size = real_data.shape[0]
        real_data = real_data.to(device)

        # ========================================
        # Treinamento do CRÍTICO (n_critic vezes)
        # ========================================
        for _ in range(n_critic):
            z = torch.randn((batch_size, z_dim), device=device)
            dados_falsos = gerador(z).detach()

            saida_reais = critico(real_data)
            saida_falsos = critico(dados_falsos)

            perda_critico = saida_falsos.mean() - saida_reais.mean()

            opt_critico.zero_grad()
            perda_critico.backward()
            opt_critico.step()

            # Clipping dos pesos do crítico para satisfazer Lipschitz
            for p in critico.parameters():
                p.data.clamp_(-clip_value, clip_value)

        # ========================================
        # Treinamento do GERADOR (1 vez)
        # ========================================
        z = torch.randn((batch_size, z_dim), device=device)
        dados_falsos = gerador(z)
        saida_falsos = critico(dados_falsos)

        perda_gerador = -saida_falsos.mean()

        opt_gerador.zero_grad()
        perda_gerador.backward()
        opt_gerador.step()

        # ========================================
        # Log
        # ========================================
        if batch % 100 == 0 or batch == len(dataloader) - 1:
            print(f"[Época {epoch:03d}] [Lote {batch:03d}/{len(dataloader)}] "
                  f"Perda Crítico: {perda_critico.item():.4f} | Perda Gerador: {perda_gerador.item():.4f}")

# %%
# Define a função de gerar dados falsos de um vetor latente fixo
def gerar(gerador, device, z_dim=100):
    gerador.eval()                  # Coloca o modelo em modo de avaliação (desativa dropout, batchnorm, etc.)
    # Desativa o cálculo de gradientes para economizar memória e acelerar a execução
    with torch.no_grad():
      z = torch.zeros((1, z_dim), device=device)
      dados_falsos = gerador(z).detach().cpu().numpy().reshape(28,28)
    return dados_falsos

# %%
z_dim = 100
# Inicializa os modelos
modelo_gerador = Gerador(z_dim)
# Inicializa os modelos
modelo_critico = Critico()

# Opcional: tenta usar GPU se disponível
# device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
device = 'cuda'
modelo_gerador.to(device)
modelo_critico.to(device)
# Exibe qual dispositivo está sendo utilizado
print(f"Usando {device}.")
# Out:
# Usando cuda.

# %%
# Gerador
print(modelo_gerador) # Imprime a arquitetura do modelo
summary(modelo_gerador, input_size=(1, 100), device=device)
# Out:
# Gerador(
#   (net): Sequential(
#     (0): Linear(in_features=100, out_features=6272, bias=True)
#     (1): Unflatten(dim=1, unflattened_size=(128, 7, 7))
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ConvTranspose2d(64, 1, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (7): Tanh()
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Gerador                                  [1, 1, 28, 28]            --
# ├─Sequential: 1-1                        [1, 1, 28, 28]            --
# │    └─Linear: 2-1                       [1, 6272]                 633,472
# │    └─Unflatten: 2-2                    [1, 128, 7, 7]            --
# │    └─BatchNorm2d: 2-3                  [1, 128, 7, 7]            256
# │    └─ConvTranspose2d: 2-4              [1, 64, 14, 14]           204,864
# │    └─ReLU: 2-5                         [1, 64, 14, 14]           --
# │    └─BatchNorm2d: 2-6                  [1, 64, 14, 14]           128
# │    └─ConvTranspose2d: 2-7              [1, 1, 28, 28]            1,601
# │    └─Tanh: 2-8                         [1, 1, 28, 28]            --
# ==========================================================================================
# Total params: 840,321
# Trainable params: 840,321
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 42.04
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.31
# Params size (MB): 3.36
# Estimated Total Size (MB): 3.67
# ==========================================================================================

# %%
# Crítico
print(modelo_critico) # Imprime a arquitetura do modelo
summary(modelo_critico, input_size=(1,1,28,28), device=device)
# Out:
# Critico(
#   (net): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=6272, out_features=1, bias=True)
#   )
# )
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Critico                                  [1, 1]                    --
# ├─Sequential: 1-1                        [1, 1]                    --
# │    └─Conv2d: 2-1                       [1, 64, 14, 14]           1,664
# │    └─LeakyReLU: 2-2                    [1, 64, 14, 14]           --
# │    └─Dropout: 2-3                      [1, 64, 14, 14]           --
# │    └─Conv2d: 2-4                       [1, 128, 7, 7]            204,928
# │    └─LeakyReLU: 2-5                    [1, 128, 7, 7]            --
# │    └─Dropout: 2-6                      [1, 128, 7, 7]            --
# │    └─Flatten: 2-7                      [1, 6272]                 --
# │    └─Linear: 2-8                       [1, 1]                    6,273
# ==========================================================================================
# Total params: 212,865
# Trainable params: 212,865
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 10.37
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.15
# Params size (MB): 0.85
# Estimated Total Size (MB): 1.01
# ==========================================================================================

# %%
# Otimizadores
lr_gerador = 1e-4   # taxa de aprendizagem do gerador
lr_critico = 1e-4   # taxa de aprendizagem do crítico
optimizador_gerador = torch.optim.RMSprop(modelo_gerador.parameters(), lr=lr_gerador)
optimizador_critico = torch.optim.RMSprop(modelo_critico.parameters(), lr=lr_critico)

# Hyper-parametros
clip_value = 0.01
n_critic = 5

# %%
num_epochs = 100  # Define o número total de épocas (iterações completas sobre o conjunto de dados de treinamento)
evolução_dado_falso = []
for epoca in range(1, num_epochs + 1):
    train_wgan(
        dataloader=train_dataloader,
        gerador=modelo_gerador,
        critico=modelo_critico,
        opt_gerador=optimizador_gerador,
        opt_critico=optimizador_critico,
        device=device,
        epoch=epoca,
        z_dim=z_dim,
        n_critic=n_critic,
        clip_value=clip_value
    )
    if epoca % 5 == 0 or epoca == 1:
      evolução_dado_falso.append(gerar(gerador=modelo_gerador, device=device, z_dim=z_dim))
print("Fim!")  # Exibe mensagem final indicando que o treinamento terminou
# Out:
# [Época 001] [Lote 000/937] Perda Crítico: -0.0915 | Perda Gerador: 0.0152
# [Época 001] [Lote 100/937] Perda Crítico: -4.6663 | Perda Gerador: -0.3866
# [Época 001] [Lote 200/937] Perda Crítico: -1.5814 | Perda Gerador: -7.5986
# [Época 001] [Lote 300/937] Perda Crítico: -1.3661 | Perda Gerador: 2.8304
# [Época 001] [Lote 400/937] Perda Crítico: -1.8018 | Perda Gerador: 4.6187
# [Época 001] [Lote 500/937] Perda Crítico: -2.1770 | Perda Gerador: 6.8862
# [Época 001] [Lote 600/937] Perda Crítico: -1.8960 | Perda Gerador: 7.5017
# [Época 001] [Lote 700/937] Perda Crítico: -1.3348 | Perda Gerador: 6.7775
# [Época 001] [Lote 800/937] Perda Crítico: -0.5045 | Perda Gerador: 3.5371
# [Época 001] [Lote 900/937] Perda Crítico: -0.2760 | Perda Gerador: 1.5913
# [Época 001] [Lote 936/937] Perda Crítico: -0.3609 | Perda Gerador: 1.1939
# [Época 002] [Lote 000/937] Perda Crítico: -0.3130 | Perda Gerador: 1.2781
# [Época 002] [Lote 100/937] Perda Crítico: -0.2837 | Perda Gerador: 2.9206
# [Época 002] [Lote 200/937] Perda Crítico: -0.4858 | Perda Gerador: 2.0509
# [Época 002] [Lote 300/937] Perda Crítico: -0.3380 | Perda Gerador: 3.2714
# [Época 002] [Lote 400/937] Perda Crítico: -0.2925 | Perda Gerador: 2.2223
# [Época 002] [Lote 500/937] Perda Crítico: -0.8749 | Perda Gerador: 2.0145
# [Época 002] [Lote 600/937] Perda Crítico: -0.3196 | Perda Gerador: 2.1635
# [Época 002] [Lote 700/937] Perda Crítico: -0.2052 | Perda Gerador: 5.9051
# [Época 002] [Lote 800/937] Perda Crítico: -0.3287 | Perda Gerador: 2.0623
# [Época 002] [Lote 900/937] Perda Crítico: -0.3025 | Perda Gerador: 1.6634
# [Época 002] [Lote 936/937] Perda Crítico: -0.2738 | Perda Gerador: 5.2269
# [Época 003] [Lote 000/937] Perda Crítico: -0.3351 | Perda Gerador: 7.3410
# [Época 003] [Lote 100/937] Perda Crítico: -0.2717 | Perda Gerador: 2.1043
# [Época 003] [Lote 200/937] Perda Crítico: -0.1593 | Perda Gerador: 3.4922
# [Época 003] [Lote 300/937] Perda Crítico: -0.1913 | Perda Gerador: 1.8566
# [Época 003] [Lote 400/937] Perda Crítico: -0.1392 | Perda Gerador: 2.1251
# [Época 003] [Lote 500/937] Perda Crítico: -0.1802 | Perda Gerador: 2.3983
# [Época 003] [Lote 600/937] Perda Crítico: -0.2457 | Perda Gerador: 2.8961
# [Época 003] [Lote 700/937] Perda Crítico: -0.1848 | Perda Gerador: 2.3417
# [Época 003] [Lote 800/937] Perda Crítico: -0.4211 | Perda Gerador: 1.1943
# [Época 003] [Lote 900/937] Perda Crítico: -0.3638 | Perda Gerador: 0.4035
# [Época 003] [Lote 936/937] Perda Crítico: -0.4559 | Perda Gerador: 0.3365
# [Época 004] [Lote 000/937] Perda Crítico: -0.2071 | Perda Gerador: 0.6773
# [Época 004] [Lote 100/937] Perda Crítico: -0.1465 | Perda Gerador: 2.1193
# [Época 004] [Lote 200/937] Perda Crítico: -0.2555 | Perda Gerador: 1.8385
# [Época 004] [Lote 300/937] Perda Crítico: -0.3602 | Perda Gerador: 0.8609
# [Época 004] [Lote 400/937] Perda Crítico: -0.1842 | Perda Gerador: 2.0266
# [Época 004] [Lote 500/937] Perda Crítico: -0.2616 | Perda Gerador: 3.2408
# [Época 004] [Lote 600/937] Perda Crítico: -0.4395 | Perda Gerador: 1.2095
# [Época 004] [Lote 700/937] Perda Crítico: -0.1784 | Perda Gerador: 4.8596
# [Época 004] [Lote 800/937] Perda Crítico: -0.0530 | Perda Gerador: 2.2586
# [Época 004] [Lote 900/937] Perda Crítico: -0.1310 | Perda Gerador: 2.4658
# [Época 004] [Lote 936/937] Perda Crítico: -0.2384 | Perda Gerador: 2.2320
# [Época 005] [Lote 000/937] Perda Crítico: -0.1762 | Perda Gerador: 2.9833
# [Época 005] [Lote 100/937] Perda Crítico: -0.2708 | Perda Gerador: 1.9377
# [Época 005] [Lote 200/937] Perda Crítico: -0.7576 | Perda Gerador: 5.0587
# [Época 005] [Lote 300/937] Perda Crítico: -0.1695 | Perda Gerador: 2.3501
# [Época 005] [Lote 400/937] Perda Crítico: -0.3950 | Perda Gerador: 1.0650
# [Época 005] [Lote 500/937] Perda Crítico: 0.2039 | Perda Gerador: 2.3537
# [Época 005] [Lote 600/937] Perda Crítico: -0.4799 | Perda Gerador: 4.6834
# [Época 005] [Lote 700/937] Perda Crítico: -0.0700 | Perda Gerador: 1.3863
# [Época 005] [Lote 800/937] Perda Crítico: -0.1625 | Perda Gerador: 1.3227
# [Época 005] [Lote 900/937] Perda Crítico: -0.2349 | Perda Gerador: 2.2527
# [Época 005] [Lote 936/937] Perda Crítico: -0.1362 | Perda Gerador: 1.7215
# [Época 006] [Lote 000/937] Perda Crítico: -0.1620 | Perda Gerador: 1.6076
# [Época 006] [Lote 100/937] Perda Crítico: -0.2851 | Perda Gerador: 0.7454
# [Época 006] [Lote 200/937] Perda Crítico: -0.2337 | Perda Gerador: 1.4849
# [Época 006] [Lote 300/937] Perda Crítico: -0.2432 | Perda Gerador: 1.1014
# [Época 006] [Lote 400/937] Perda Crítico: -0.1277 | Perda Gerador: 2.2543
# [Época 006] [Lote 500/937] Perda Crítico: -0.1320 | Perda Gerador: 2.4684
# [Época 006] [Lote 600/937] Perda Crítico: -0.2516 | Perda Gerador: 2.1276
# [Época 006] [Lote 700/937] Perda Crítico: -0.2078 | Perda Gerador: 1.2101
# [Época 006] [Lote 800/937] Perda Crítico: -0.2320 | Perda Gerador: 1.7922
# [Época 006] [Lote 900/937] Perda Crítico: -0.0605 | Perda Gerador: 2.8094
# [Época 006] [Lote 936/937] Perda Crítico: 0.2837 | Perda Gerador: 1.6755
# [Época 007] [Lote 000/937] Perda Crítico: -0.1242 | Perda Gerador: 1.6418
# [Época 007] [Lote 100/937] Perda Crítico: -0.5840 | Perda Gerador: 6.0792
# [Época 007] [Lote 200/937] Perda Crítico: -0.1543 | Perda Gerador: 1.2962
# [Época 007] [Lote 300/937] Perda Crítico: 0.0531 | Perda Gerador: 1.9334
# [Época 007] [Lote 400/937] Perda Crítico: -0.2030 | Perda Gerador: 3.6925
# [Época 007] [Lote 500/937] Perda Crítico: -0.2643 | Perda Gerador: 1.1561
# [Época 007] [Lote 600/937] Perda Crítico: -0.2227 | Perda Gerador: 2.3153
# [Época 007] [Lote 700/937] Perda Crítico: -0.0915 | Perda Gerador: 2.2947
# [Época 007] [Lote 800/937] Perda Crítico: -0.2836 | Perda Gerador: 3.6943
# [Época 007] [Lote 900/937] Perda Crítico: -0.0791 | Perda Gerador: 1.8740
# [Época 007] [Lote 936/937] Perda Crítico: -0.1089 | Perda Gerador: 2.5833
# [Época 008] [Lote 000/937] Perda Crítico: -0.1355 | Perda Gerador: 2.1944
# [Época 008] [Lote 100/937] Perda Crítico: -0.1415 | Perda Gerador: 0.9255
# [Época 008] [Lote 200/937] Perda Crítico: -0.0992 | Perda Gerador: 1.5314
# [Época 008] [Lote 300/937] Perda Crítico: -0.0480 | Perda Gerador: 1.8777
# [Época 008] [Lote 400/937] Perda Crítico: -0.0598 | Perda Gerador: 1.1941
# [Época 008] [Lote 500/937] Perda Crítico: -0.1029 | Perda Gerador: 2.0996
# [Época 008] [Lote 600/937] Perda Crítico: 0.1033 | Perda Gerador: 1.7959
# [Época 008] [Lote 700/937] Perda Crítico: -0.5418 | Perda Gerador: 4.1692
# [Época 008] [Lote 800/937] Perda Crítico: -0.2847 | Perda Gerador: 1.2465
# [Época 008] [Lote 900/937] Perda Crítico: -0.2226 | Perda Gerador: 2.4002
# [Época 008] [Lote 936/937] Perda Crítico: -0.1363 | Perda Gerador: 0.7684
# [Época 009] [Lote 000/937] Perda Crítico: -0.0080 | Perda Gerador: 1.0465
# [Época 009] [Lote 100/937] Perda Crítico: -0.1576 | Perda Gerador: 1.8203
# [Época 009] [Lote 200/937] Perda Crítico: 0.0132 | Perda Gerador: 2.4418
# [Época 009] [Lote 300/937] Perda Crítico: -0.1548 | Perda Gerador: 2.3911
# [Época 009] [Lote 400/937] Perda Crítico: -0.1101 | Perda Gerador: 1.3821
# [Época 009] [Lote 500/937] Perda Crítico: -0.2934 | Perda Gerador: 2.0023
# [Época 009] [Lote 600/937] Perda Crítico: -0.1137 | Perda Gerador: 0.6935
# [Época 009] [Lote 700/937] Perda Crítico: -0.1379 | Perda Gerador: 2.0968
# [Época 009] [Lote 800/937] Perda Crítico: -0.2324 | Perda Gerador: 1.2897
# [Época 009] [Lote 900/937] Perda Crítico: -0.1774 | Perda Gerador: 2.7627
# [Época 009] [Lote 936/937] Perda Crítico: -0.2041 | Perda Gerador: 1.1611
# [Época 010] [Lote 000/937] Perda Crítico: 0.2339 | Perda Gerador: 1.6146
# [Época 010] [Lote 100/937] Perda Crítico: -0.3622 | Perda Gerador: 1.9634
# [Época 010] [Lote 200/937] Perda Crítico: -0.0091 | Perda Gerador: 1.3540
# [Época 010] [Lote 300/937] Perda Crítico: -0.0719 | Perda Gerador: 1.5586
# [Época 010] [Lote 400/937] Perda Crítico: -0.2527 | Perda Gerador: 2.1504
# [Época 010] [Lote 500/937] Perda Crítico: -0.4551 | Perda Gerador: 5.9321
# [Época 010] [Lote 600/937] Perda Crítico: -0.2076 | Perda Gerador: 0.6201
# [Época 010] [Lote 700/937] Perda Crítico: -0.1471 | Perda Gerador: 2.7544
# [Época 010] [Lote 800/937] Perda Crítico: -0.1223 | Perda Gerador: 1.6500
# [Época 010] [Lote 900/937] Perda Crítico: -0.1833 | Perda Gerador: 1.1160
# [Época 010] [Lote 936/937] Perda Crítico: -0.0731 | Perda Gerador: 2.8245
# [Época 011] [Lote 000/937] Perda Crítico: -0.3671 | Perda Gerador: 1.5559
# [Época 011] [Lote 100/937] Perda Crítico: -0.3004 | Perda Gerador: 5.2609
# [Época 011] [Lote 200/937] Perda Crítico: -0.8372 | Perda Gerador: 5.6453
# [Época 011] [Lote 300/937] Perda Crítico: -0.3842 | Perda Gerador: 3.5787
# [Época 011] [Lote 400/937] Perda Crítico: -0.0886 | Perda Gerador: 2.6565
# [Época 011] [Lote 500/937] Perda Crítico: -0.2657 | Perda Gerador: 0.5638
# [Época 011] [Lote 600/937] Perda Crítico: -0.1517 | Perda Gerador: 2.7116
# [Época 011] [Lote 700/937] Perda Crítico: -0.2435 | Perda Gerador: 1.7855
# [Época 011] [Lote 800/937] Perda Crítico: -0.1393 | Perda Gerador: 0.6525
# [Época 011] [Lote 900/937] Perda Crítico: -0.3809 | Perda Gerador: 3.2669
# [Época 011] [Lote 936/937] Perda Crítico: -0.1304 | Perda Gerador: 0.7134
# [Época 012] [Lote 000/937] Perda Crítico: -0.2511 | Perda Gerador: 0.4746
# [Época 012] [Lote 100/937] Perda Crítico: -0.1827 | Perda Gerador: 3.3098
# [Época 012] [Lote 200/937] Perda Crítico: 0.0046 | Perda Gerador: 3.2584
# [Época 012] [Lote 300/937] Perda Crítico: 0.0246 | Perda Gerador: 2.9300
# [Época 012] [Lote 400/937] Perda Crítico: -0.5010 | Perda Gerador: 4.2148
# [Época 012] [Lote 500/937] Perda Crítico: -0.6273 | Perda Gerador: 1.5102
# [Época 012] [Lote 600/937] Perda Crítico: -0.1315 | Perda Gerador: 2.6035
# [Época 012] [Lote 700/937] Perda Crítico: -0.1650 | Perda Gerador: 1.4442
# [Época 012] [Lote 800/937] Perda Crítico: -0.1718 | Perda Gerador: 2.6047
# [Época 012] [Lote 900/937] Perda Crítico: -0.0767 | Perda Gerador: 2.8028
# [Época 012] [Lote 936/937] Perda Crítico: -0.2022 | Perda Gerador: 3.2600
# [Época 013] [Lote 000/937] Perda Crítico: -0.1853 | Perda Gerador: 3.5042
# [Época 013] [Lote 100/937] Perda Crítico: 0.0138 | Perda Gerador: 0.4395
# [Época 013] [Lote 200/937] Perda Crítico: -0.0875 | Perda Gerador: 2.5721
# [Época 013] [Lote 300/937] Perda Crítico: -0.0529 | Perda Gerador: 2.2470
# [Época 013] [Lote 400/937] Perda Crítico: -0.2869 | Perda Gerador: 2.9683
# [Época 013] [Lote 500/937] Perda Crítico: -0.2704 | Perda Gerador: 4.2640
# [Época 013] [Lote 600/937] Perda Crítico: -0.2198 | Perda Gerador: 3.0375
# [Época 013] [Lote 700/937] Perda Crítico: -0.2406 | Perda Gerador: 1.5121
# [Época 013] [Lote 800/937] Perda Crítico: 0.0761 | Perda Gerador: 1.2329
# [Época 013] [Lote 900/937] Perda Crítico: -0.0881 | Perda Gerador: 1.0565
# [Época 013] [Lote 936/937] Perda Crítico: -0.2165 | Perda Gerador: 0.9396
# [Época 014] [Lote 000/937] Perda Crítico: -0.1545 | Perda Gerador: 1.5794
# [Época 014] [Lote 100/937] Perda Crítico: -0.0786 | Perda Gerador: 4.1246
# [Época 014] [Lote 200/937] Perda Crítico: -0.0674 | Perda Gerador: 0.4335
# [Época 014] [Lote 300/937] Perda Crítico: -0.1113 | Perda Gerador: 1.5617
# [Época 014] [Lote 400/937] Perda Crítico: -0.3742 | Perda Gerador: 0.3592
# [Época 014] [Lote 500/937] Perda Crítico: -0.0889 | Perda Gerador: 3.5687
# [Época 014] [Lote 600/937] Perda Crítico: -0.2356 | Perda Gerador: 3.6114
# [Época 014] [Lote 700/937] Perda Crítico: -0.2293 | Perda Gerador: -0.2551
# [Época 014] [Lote 800/937] Perda Crítico: -0.3117 | Perda Gerador: 3.1970
# [Época 014] [Lote 900/937] Perda Crítico: 0.3776 | Perda Gerador: 0.5346
# [Época 014] [Lote 936/937] Perda Crítico: -0.0816 | Perda Gerador: 0.7767
# [Época 015] [Lote 000/937] Perda Crítico: -0.1915 | Perda Gerador: 0.3117
# [Época 015] [Lote 100/937] Perda Crítico: 0.1195 | Perda Gerador: 0.4648
# [Época 015] [Lote 200/937] Perda Crítico: -0.0342 | Perda Gerador: 5.8304
# [Época 015] [Lote 300/937] Perda Crítico: -0.1598 | Perda Gerador: 2.0709
# [Época 015] [Lote 400/937] Perda Crítico: -0.0551 | Perda Gerador: 1.8896
# [Época 015] [Lote 500/937] Perda Crítico: -0.2379 | Perda Gerador: 0.2811
# [Época 015] [Lote 600/937] Perda Crítico: -0.8916 | Perda Gerador: 1.4657
# [Época 015] [Lote 700/937] Perda Crítico: -0.0662 | Perda Gerador: 0.7508
# [Época 015] [Lote 800/937] Perda Crítico: -0.3164 | Perda Gerador: 1.0988
# [Época 015] [Lote 900/937] Perda Crítico: -0.1103 | Perda Gerador: 0.9511
# [Época 015] [Lote 936/937] Perda Crítico: -0.2012 | Perda Gerador: 2.6548
# [Época 016] [Lote 000/937] Perda Crítico: -0.8081 | Perda Gerador: 4.5338
# [Época 016] [Lote 100/937] Perda Crítico: -0.0662 | Perda Gerador: -0.2145
# [Época 016] [Lote 200/937] Perda Crítico: 0.2974 | Perda Gerador: 2.5294
# [Época 016] [Lote 300/937] Perda Crítico: -0.1217 | Perda Gerador: 1.9666
# [Época 016] [Lote 400/937] Perda Crítico: -0.1401 | Perda Gerador: 3.3898
# [Época 016] [Lote 500/937] Perda Crítico: -0.0019 | Perda Gerador: 4.3651
# [Época 016] [Lote 600/937] Perda Crítico: -0.0660 | Perda Gerador: 1.3471
# [Época 016] [Lote 700/937] Perda Crítico: -0.5746 | Perda Gerador: 1.1345
# [Época 016] [Lote 800/937] Perda Crítico: -0.1023 | Perda Gerador: 1.1975
# [Época 016] [Lote 900/937] Perda Crítico: -0.1876 | Perda Gerador: 5.4334
# [Época 016] [Lote 936/937] Perda Crítico: -0.3449 | Perda Gerador: 4.2542
# [Época 017] [Lote 000/937] Perda Crítico: -0.1688 | Perda Gerador: 4.3974
# [Época 017] [Lote 100/937] Perda Crítico: 0.0708 | Perda Gerador: 0.4186
# [Época 017] [Lote 200/937] Perda Crítico: -0.6903 | Perda Gerador: 0.9708
# [Época 017] [Lote 300/937] Perda Crítico: 0.1005 | Perda Gerador: 1.2274
# [Época 017] [Lote 400/937] Perda Crítico: -0.1077 | Perda Gerador: 2.7367
# [Época 017] [Lote 500/937] Perda Crítico: -0.1108 | Perda Gerador: 3.1467
# [Época 017] [Lote 600/937] Perda Crítico: 0.0595 | Perda Gerador: 2.0208
# [Época 017] [Lote 700/937] Perda Crítico: -0.1679 | Perda Gerador: 3.2489
# [Época 017] [Lote 800/937] Perda Crítico: -0.0843 | Perda Gerador: 0.9879
# [Época 017] [Lote 900/937] Perda Crítico: -0.0022 | Perda Gerador: 2.1058
# [Época 017] [Lote 936/937] Perda Crítico: -0.0946 | Perda Gerador: 2.1315
# [Época 018] [Lote 000/937] Perda Crítico: -0.1860 | Perda Gerador: 1.9588
# [Época 018] [Lote 100/937] Perda Crítico: -0.0954 | Perda Gerador: 1.0101
# [Época 018] [Lote 200/937] Perda Crítico: -0.1094 | Perda Gerador: -0.3901
# [Época 018] [Lote 300/937] Perda Crítico: -0.1170 | Perda Gerador: 2.0613
# [Época 018] [Lote 400/937] Perda Crítico: -0.1071 | Perda Gerador: 2.6067
# [Época 018] [Lote 500/937] Perda Crítico: -1.1907 | Perda Gerador: 5.7024
# [Época 018] [Lote 600/937] Perda Crítico: -0.5338 | Perda Gerador: 1.3140
# [Época 018] [Lote 700/937] Perda Crítico: -0.0280 | Perda Gerador: 3.7037
# [Época 018] [Lote 800/937] Perda Crítico: -0.0917 | Perda Gerador: 0.4681
# [Época 018] [Lote 900/937] Perda Crítico: 0.0221 | Perda Gerador: 0.4176
# [Época 018] [Lote 936/937] Perda Crítico: -0.5233 | Perda Gerador: -0.9781
# [Época 019] [Lote 000/937] Perda Crítico: -0.1761 | Perda Gerador: -0.4614
# [Época 019] [Lote 100/937] Perda Crítico: 0.0588 | Perda Gerador: 2.0328
# [Época 019] [Lote 200/937] Perda Crítico: -0.0685 | Perda Gerador: 3.2407
# [Época 019] [Lote 300/937] Perda Crítico: -0.2827 | Perda Gerador: 0.0965
# [Época 019] [Lote 400/937] Perda Crítico: -0.5398 | Perda Gerador: 4.1142
# [Época 019] [Lote 500/937] Perda Crítico: -0.0148 | Perda Gerador: 1.1953
# [Época 019] [Lote 600/937] Perda Crítico: -0.0403 | Perda Gerador: 2.1318
# [Época 019] [Lote 700/937] Perda Crítico: -0.5104 | Perda Gerador: 3.4059
# [Época 019] [Lote 800/937] Perda Crítico: -0.0520 | Perda Gerador: 1.6641
# [Época 019] [Lote 900/937] Perda Crítico: -0.0383 | Perda Gerador: 2.0668
# [Época 019] [Lote 936/937] Perda Crítico: -0.0259 | Perda Gerador: 1.9805
# [Época 020] [Lote 000/937] Perda Crítico: -0.1097 | Perda Gerador: 2.0330
# [Época 020] [Lote 100/937] Perda Crítico: -0.0857 | Perda Gerador: 2.2327
# [Época 020] [Lote 200/937] Perda Crítico: -0.0957 | Perda Gerador: 1.8986
# [Época 020] [Lote 300/937] Perda Crítico: -0.0165 | Perda Gerador: 1.8794
# [Época 020] [Lote 400/937] Perda Crítico: -0.0728 | Perda Gerador: 1.3931
# [Época 020] [Lote 500/937] Perda Crítico: -0.4917 | Perda Gerador: -0.0137
# [Época 020] [Lote 600/937] Perda Crítico: 0.0467 | Perda Gerador: 2.3505
# [Época 020] [Lote 700/937] Perda Crítico: -0.0463 | Perda Gerador: 1.2764
# [Época 020] [Lote 800/937] Perda Crítico: -0.0323 | Perda Gerador: 0.9553
# [Época 020] [Lote 900/937] Perda Crítico: -0.3010 | Perda Gerador: 0.1641
# [Época 020] [Lote 936/937] Perda Crítico: -0.3900 | Perda Gerador: 0.3552
# [Época 021] [Lote 000/937] Perda Crítico: -0.0080 | Perda Gerador: 0.7503
# [Época 021] [Lote 100/937] Perda Crítico: 0.0510 | Perda Gerador: 0.3020
# [Época 021] [Lote 200/937] Perda Crítico: -0.0367 | Perda Gerador: 1.9012
# [Época 021] [Lote 300/937] Perda Crítico: -0.6583 | Perda Gerador: 1.5347
# [Época 021] [Lote 400/937] Perda Crítico: -0.1334 | Perda Gerador: 1.4991
# [Época 021] [Lote 500/937] Perda Crítico: -0.0110 | Perda Gerador: 2.3895
# [Época 021] [Lote 600/937] Perda Crítico: -0.2655 | Perda Gerador: 2.6803
# [Época 021] [Lote 700/937] Perda Crítico: 0.0562 | Perda Gerador: -0.3372
# [Época 021] [Lote 800/937] Perda Crítico: -0.0388 | Perda Gerador: -0.1297
# [Época 021] [Lote 900/937] Perda Crítico: 0.1290 | Perda Gerador: 1.0226
# [Época 021] [Lote 936/937] Perda Crítico: 0.2317 | Perda Gerador: 3.9318
# [Época 022] [Lote 000/937] Perda Crítico: 0.0511 | Perda Gerador: 2.3499
# [Época 022] [Lote 100/937] Perda Crítico: 0.1834 | Perda Gerador: 2.8614
# [Época 022] [Lote 200/937] Perda Crítico: -0.0388 | Perda Gerador: 1.1866
# [Época 022] [Lote 300/937] Perda Crítico: -0.1814 | Perda Gerador: 1.7788
# [Época 022] [Lote 400/937] Perda Crítico: -0.0479 | Perda Gerador: 1.5446
# [Época 022] [Lote 500/937] Perda Crítico: -0.6806 | Perda Gerador: 5.0553
# [Época 022] [Lote 600/937] Perda Crítico: -0.0479 | Perda Gerador: 0.8811
# [Época 022] [Lote 700/937] Perda Crítico: -1.5145 | Perda Gerador: 0.7261
# [Época 022] [Lote 800/937] Perda Crítico: -0.0896 | Perda Gerador: 1.1902
# [Época 022] [Lote 900/937] Perda Crítico: -0.0987 | Perda Gerador: 1.4164
# [Época 022] [Lote 936/937] Perda Crítico: 0.0094 | Perda Gerador: 2.5502
# [Época 023] [Lote 000/937] Perda Crítico: 0.0155 | Perda Gerador: 1.6501
# [Época 023] [Lote 100/937] Perda Crítico: 0.2325 | Perda Gerador: 4.8289
# [Época 023] [Lote 200/937] Perda Crítico: -0.0674 | Perda Gerador: 2.2777
# [Época 023] [Lote 300/937] Perda Crítico: 0.4750 | Perda Gerador: 0.1715
# [Época 023] [Lote 400/937] Perda Crítico: 0.1904 | Perda Gerador: 1.8083
# [Época 023] [Lote 500/937] Perda Crítico: -0.2748 | Perda Gerador: 0.9365
# [Época 023] [Lote 600/937] Perda Crítico: -0.0412 | Perda Gerador: 4.8907
# [Época 023] [Lote 700/937] Perda Crítico: -0.2126 | Perda Gerador: 1.5573
# [Época 023] [Lote 800/937] Perda Crítico: -0.4368 | Perda Gerador: -0.2236
# [Época 023] [Lote 900/937] Perda Crítico: -0.0294 | Perda Gerador: 1.2234
# [Época 023] [Lote 936/937] Perda Crítico: -0.0613 | Perda Gerador: 2.3606
# [Época 024] [Lote 000/937] Perda Crítico: -0.2797 | Perda Gerador: 3.3383
# [Época 024] [Lote 100/937] Perda Crítico: 0.2622 | Perda Gerador: 1.2882
# [Época 024] [Lote 200/937] Perda Crítico: -0.3246 | Perda Gerador: 0.3122
# [Época 024] [Lote 300/937] Perda Crítico: -0.0956 | Perda Gerador: -0.6982
# [Época 024] [Lote 400/937] Perda Crítico: -0.0614 | Perda Gerador: 2.7776
# [Época 024] [Lote 500/937] Perda Crítico: -0.1997 | Perda Gerador: 0.5612
# [Época 024] [Lote 600/937] Perda Crítico: 0.2391 | Perda Gerador: 0.8483
# [Época 024] [Lote 700/937] Perda Crítico: -0.1168 | Perda Gerador: 1.8608
# [Época 024] [Lote 800/937] Perda Crítico: -0.1232 | Perda Gerador: 2.4169
# [Época 024] [Lote 900/937] Perda Crítico: -0.2370 | Perda Gerador: 4.5454
# [Época 024] [Lote 936/937] Perda Crítico: -0.1164 | Perda Gerador: 0.3479
# [Época 025] [Lote 000/937] Perda Crítico: -0.1908 | Perda Gerador: -0.0649
# [Época 025] [Lote 100/937] Perda Crítico: -0.0059 | Perda Gerador: 1.0467
# [Época 025] [Lote 200/937] Perda Crítico: -0.1401 | Perda Gerador: 3.1292
# [Época 025] [Lote 300/937] Perda Crítico: -0.3398 | Perda Gerador: -0.1404
# [Época 025] [Lote 400/937] Perda Crítico: -0.3651 | Perda Gerador: 4.0497
# [Época 025] [Lote 500/937] Perda Crítico: -0.0343 | Perda Gerador: 2.0510
# [Época 025] [Lote 600/937] Perda Crítico: 0.4629 | Perda Gerador: 0.9401
# [Época 025] [Lote 700/937] Perda Crítico: -0.1923 | Perda Gerador: -0.6099
# [Época 025] [Lote 800/937] Perda Crítico: -0.2997 | Perda Gerador: 5.1275
# [Época 025] [Lote 900/937] Perda Crítico: 0.0633 | Perda Gerador: 0.5819
# [Época 025] [Lote 936/937] Perda Crítico: -0.2124 | Perda Gerador: 3.5702
# [Época 026] [Lote 000/937] Perda Crítico: 0.0028 | Perda Gerador: 1.8962
# [Época 026] [Lote 100/937] Perda Crítico: -0.0704 | Perda Gerador: 1.7314
# [Época 026] [Lote 200/937] Perda Crítico: 0.4979 | Perda Gerador: 0.3957
# [Época 026] [Lote 300/937] Perda Crítico: -0.1593 | Perda Gerador: 2.3191
# [Época 026] [Lote 400/937] Perda Crítico: 0.1600 | Perda Gerador: 2.9521
# [Época 026] [Lote 500/937] Perda Crítico: -0.2069 | Perda Gerador: 1.1159
# [Época 026] [Lote 600/937] Perda Crítico: -0.3834 | Perda Gerador: 3.0008
# [Época 026] [Lote 700/937] Perda Crítico: -0.1701 | Perda Gerador: 3.1217
# [Época 026] [Lote 800/937] Perda Crítico: -0.3026 | Perda Gerador: 0.4417
# [Época 026] [Lote 900/937] Perda Crítico: 0.0017 | Perda Gerador: 1.7055
# [Época 026] [Lote 936/937] Perda Crítico: 0.1289 | Perda Gerador: -0.6692
# [Época 027] [Lote 000/937] Perda Crítico: 0.1348 | Perda Gerador: 0.3842
# [Época 027] [Lote 100/937] Perda Crítico: -0.0267 | Perda Gerador: 1.1494
# [Época 027] [Lote 200/937] Perda Crítico: -0.0673 | Perda Gerador: 1.9009
# [Época 027] [Lote 300/937] Perda Crítico: -0.5626 | Perda Gerador: 2.3572
# [Época 027] [Lote 400/937] Perda Crítico: 0.3047 | Perda Gerador: 0.8713
# [Época 027] [Lote 500/937] Perda Crítico: 0.0640 | Perda Gerador: 1.8791
# [Época 027] [Lote 600/937] Perda Crítico: -0.3371 | Perda Gerador: 3.4443
# [Época 027] [Lote 700/937] Perda Crítico: -0.9609 | Perda Gerador: 4.8602
# [Época 027] [Lote 800/937] Perda Crítico: -0.0466 | Perda Gerador: 2.1157
# [Época 027] [Lote 900/937] Perda Crítico: -0.0891 | Perda Gerador: -0.4314
# [Época 027] [Lote 936/937] Perda Crítico: -0.2072 | Perda Gerador: 0.4490
# [Época 028] [Lote 000/937] Perda Crítico: -0.3835 | Perda Gerador: 2.9525
# [Época 028] [Lote 100/937] Perda Crítico: -0.1557 | Perda Gerador: 2.3205
# [Época 028] [Lote 200/937] Perda Crítico: -0.3083 | Perda Gerador: 0.8995
# [Época 028] [Lote 300/937] Perda Crítico: -0.0296 | Perda Gerador: 1.7618
# [Época 028] [Lote 400/937] Perda Crítico: -0.0924 | Perda Gerador: 1.2613
# [Época 028] [Lote 500/937] Perda Crítico: -0.0818 | Perda Gerador: 0.3762
# [Época 028] [Lote 600/937] Perda Crítico: -0.0294 | Perda Gerador: 1.4200
# [Época 028] [Lote 700/937] Perda Crítico: -0.4040 | Perda Gerador: 0.3296
# [Época 028] [Lote 800/937] Perda Crítico: -0.1517 | Perda Gerador: 2.0789
# [Época 028] [Lote 900/937] Perda Crítico: -0.0531 | Perda Gerador: 2.0983
# [Época 028] [Lote 936/937] Perda Crítico: 0.0666 | Perda Gerador: 0.6632
# [Época 029] [Lote 000/937] Perda Crítico: -0.7206 | Perda Gerador: 3.9653
# [Época 029] [Lote 100/937] Perda Crítico: -0.5773 | Perda Gerador: 6.9765
# [Época 029] [Lote 200/937] Perda Crítico: 0.2955 | Perda Gerador: 1.8372
# [Época 029] [Lote 300/937] Perda Crítico: -0.3385 | Perda Gerador: 5.4973
# [Época 029] [Lote 400/937] Perda Crítico: -0.1118 | Perda Gerador: -0.2798
# [Época 029] [Lote 500/937] Perda Crítico: -0.0213 | Perda Gerador: 2.5791
# [Época 029] [Lote 600/937] Perda Crítico: 0.2744 | Perda Gerador: 4.8521
# [Época 029] [Lote 700/937] Perda Crítico: 0.0044 | Perda Gerador: 0.9735
# [Época 029] [Lote 800/937] Perda Crítico: -0.0568 | Perda Gerador: 2.3504
# [Época 029] [Lote 900/937] Perda Crítico: -0.0448 | Perda Gerador: -0.3138
# [Época 029] [Lote 936/937] Perda Crítico: -0.2675 | Perda Gerador: 4.2454
# [Época 030] [Lote 000/937] Perda Crítico: -0.4276 | Perda Gerador: 3.9228
# [Época 030] [Lote 100/937] Perda Crítico: 0.0824 | Perda Gerador: 1.4592
# [Época 030] [Lote 200/937] Perda Crítico: 0.0894 | Perda Gerador: 0.8966
# [Época 030] [Lote 300/937] Perda Crítico: -0.1966 | Perda Gerador: 2.4406
# [Época 030] [Lote 400/937] Perda Crítico: -0.0185 | Perda Gerador: 2.7729
# [Época 030] [Lote 500/937] Perda Crítico: -0.5694 | Perda Gerador: 7.0935
# [Época 030] [Lote 600/937] Perda Crítico: -0.2368 | Perda Gerador: 1.8789
# [Época 030] [Lote 700/937] Perda Crítico: -0.1342 | Perda Gerador: 2.7112
# [Época 030] [Lote 800/937] Perda Crítico: -0.0950 | Perda Gerador: -0.7686
# [Época 030] [Lote 900/937] Perda Crítico: -0.3333 | Perda Gerador: 0.2215
# [Época 030] [Lote 936/937] Perda Crítico: 0.4715 | Perda Gerador: 3.1867
# [Época 031] [Lote 000/937] Perda Crítico: 0.0982 | Perda Gerador: 0.4932
# [Época 031] [Lote 100/937] Perda Crítico: -0.1091 | Perda Gerador: 0.9339
# [Época 031] [Lote 200/937] Perda Crítico: -0.2825 | Perda Gerador: 0.6617
# [Época 031] [Lote 300/937] Perda Crítico: -0.0999 | Perda Gerador: 2.6977
# [Época 031] [Lote 400/937] Perda Crítico: -0.2388 | Perda Gerador: -0.0369
# [Época 031] [Lote 500/937] Perda Crítico: -0.4033 | Perda Gerador: 4.3637
# [Época 031] [Lote 600/937] Perda Crítico: 0.2368 | Perda Gerador: 4.0686
# [Época 031] [Lote 700/937] Perda Crítico: 0.0130 | Perda Gerador: 3.2423
# [Época 031] [Lote 800/937] Perda Crítico: -0.3083 | Perda Gerador: 3.4515
# [Época 031] [Lote 900/937] Perda Crítico: -0.0574 | Perda Gerador: 3.1637
# [Época 031] [Lote 936/937] Perda Crítico: -0.0602 | Perda Gerador: 0.2097
# [Época 032] [Lote 000/937] Perda Crítico: -0.0653 | Perda Gerador: 0.6930
# [Época 032] [Lote 100/937] Perda Crítico: -0.0407 | Perda Gerador: 3.4162
# [Época 032] [Lote 200/937] Perda Crítico: -0.4603 | Perda Gerador: 1.1364
# [Época 032] [Lote 300/937] Perda Crítico: -0.4560 | Perda Gerador: 6.2747
# [Época 032] [Lote 400/937] Perda Crítico: -0.0989 | Perda Gerador: 0.5053
# [Época 032] [Lote 500/937] Perda Crítico: 0.0213 | Perda Gerador: 2.5204
# [Época 032] [Lote 600/937] Perda Crítico: -0.2277 | Perda Gerador: 4.2007
# [Época 032] [Lote 700/937] Perda Crítico: -0.0786 | Perda Gerador: 0.6078
# [Época 032] [Lote 800/937] Perda Crítico: 0.1472 | Perda Gerador: 0.3497
# [Época 032] [Lote 900/937] Perda Crítico: -0.8183 | Perda Gerador: 5.3076
# [Época 032] [Lote 936/937] Perda Crítico: 0.2190 | Perda Gerador: 0.5199
# [Época 033] [Lote 000/937] Perda Crítico: 0.0825 | Perda Gerador: 0.5692
# [Época 033] [Lote 100/937] Perda Crítico: -0.2877 | Perda Gerador: -0.7858
# [Época 033] [Lote 200/937] Perda Crítico: 0.0183 | Perda Gerador: -0.2497
# [Época 033] [Lote 300/937] Perda Crítico: -0.1801 | Perda Gerador: -0.0814
# [Época 033] [Lote 400/937] Perda Crítico: -0.2480 | Perda Gerador: 2.1041
# [Época 033] [Lote 500/937] Perda Crítico: -0.1541 | Perda Gerador: 2.4558
# [Época 033] [Lote 600/937] Perda Crítico: -0.2741 | Perda Gerador: -1.3769
# [Época 033] [Lote 700/937] Perda Crítico: -0.4591 | Perda Gerador: 5.1540
# [Época 033] [Lote 800/937] Perda Crítico: -0.1086 | Perda Gerador: 1.7118
# [Época 033] [Lote 900/937] Perda Crítico: -0.0320 | Perda Gerador: 0.6651
# [Época 033] [Lote 936/937] Perda Crítico: -0.1460 | Perda Gerador: 0.7925
# [Época 034] [Lote 000/937] Perda Crítico: 0.0394 | Perda Gerador: 1.3828
# [Época 034] [Lote 100/937] Perda Crítico: -0.0205 | Perda Gerador: 0.7123
# [Época 034] [Lote 200/937] Perda Crítico: -0.3108 | Perda Gerador: -0.8166
# [Época 034] [Lote 300/937] Perda Crítico: -0.1607 | Perda Gerador: 4.3664
# [Época 034] [Lote 400/937] Perda Crítico: -0.4599 | Perda Gerador: 4.1016
# [Época 034] [Lote 500/937] Perda Crítico: -0.0907 | Perda Gerador: 2.5481
# [Época 034] [Lote 600/937] Perda Crítico: 0.0333 | Perda Gerador: -0.6202
# [Época 034] [Lote 700/937] Perda Crítico: -0.0372 | Perda Gerador: 4.1941
# [Época 034] [Lote 800/937] Perda Crítico: -0.0052 | Perda Gerador: 0.8129
# [Época 034] [Lote 900/937] Perda Crítico: 0.0591 | Perda Gerador: 2.8365
# [Época 034] [Lote 936/937] Perda Crítico: -0.4178 | Perda Gerador: 0.7887
# [Época 035] [Lote 000/937] Perda Crítico: 0.0160 | Perda Gerador: 0.9084
# [Época 035] [Lote 100/937] Perda Crítico: -0.0471 | Perda Gerador: 2.7135
# [Época 035] [Lote 200/937] Perda Crítico: -1.2725 | Perda Gerador: 6.1306
# [Época 035] [Lote 300/937] Perda Crítico: -0.3156 | Perda Gerador: 1.1619
# [Época 035] [Lote 400/937] Perda Crítico: -0.4095 | Perda Gerador: 0.2523
# [Época 035] [Lote 500/937] Perda Crítico: -0.1713 | Perda Gerador: 0.2513
# [Época 035] [Lote 600/937] Perda Crítico: -0.2441 | Perda Gerador: 0.1570
# [Época 035] [Lote 700/937] Perda Crítico: -0.5366 | Perda Gerador: -0.5389
# [Época 035] [Lote 800/937] Perda Crítico: -0.1123 | Perda Gerador: 1.4362
# [Época 035] [Lote 900/937] Perda Crítico: 0.0577 | Perda Gerador: 0.6120
# [Época 035] [Lote 936/937] Perda Crítico: 0.0020 | Perda Gerador: 0.9693
# [Época 036] [Lote 000/937] Perda Crítico: -0.1037 | Perda Gerador: 2.2709
# [Época 036] [Lote 100/937] Perda Crítico: -0.2305 | Perda Gerador: -0.4166
# [Época 036] [Lote 200/937] Perda Crítico: -0.0242 | Perda Gerador: 2.3419
# [Época 036] [Lote 300/937] Perda Crítico: 0.3002 | Perda Gerador: 4.3535
# [Época 036] [Lote 400/937] Perda Crítico: -0.2241 | Perda Gerador: 4.3865
# [Época 036] [Lote 500/937] Perda Crítico: 0.0749 | Perda Gerador: 4.7735
# [Época 036] [Lote 600/937] Perda Crítico: -0.2547 | Perda Gerador: -0.2397
# [Época 036] [Lote 700/937] Perda Crítico: -0.0860 | Perda Gerador: 3.1484
# [Época 036] [Lote 800/937] Perda Crítico: -0.1212 | Perda Gerador: 0.6869
# [Época 036] [Lote 900/937] Perda Crítico: 0.3071 | Perda Gerador: 3.0673
# [Época 036] [Lote 936/937] Perda Crítico: 0.0565 | Perda Gerador: 1.1199
# [Época 037] [Lote 000/937] Perda Crítico: -0.3508 | Perda Gerador: -0.0682
# [Época 037] [Lote 100/937] Perda Crítico: -0.1661 | Perda Gerador: 0.6179
# [Época 037] [Lote 200/937] Perda Crítico: 0.0400 | Perda Gerador: 1.5745
# [Época 037] [Lote 300/937] Perda Crítico: -0.2676 | Perda Gerador: 1.9784
# [Época 037] [Lote 400/937] Perda Crítico: -0.1305 | Perda Gerador: 2.4355
# [Época 037] [Lote 500/937] Perda Crítico: -0.0530 | Perda Gerador: -0.0389
# [Época 037] [Lote 600/937] Perda Crítico: -0.4170 | Perda Gerador: 2.4215
# [Época 037] [Lote 700/937] Perda Crítico: 0.0596 | Perda Gerador: 1.8042
# [Época 037] [Lote 800/937] Perda Crítico: 0.1368 | Perda Gerador: 4.3988
# [Época 037] [Lote 900/937] Perda Crítico: 0.3792 | Perda Gerador: 0.1151
# [Época 037] [Lote 936/937] Perda Crítico: 0.0690 | Perda Gerador: 1.0589
# [Época 038] [Lote 000/937] Perda Crítico: -0.0645 | Perda Gerador: 1.1928
# [Época 038] [Lote 100/937] Perda Crítico: 0.0685 | Perda Gerador: 0.9715
# [Época 038] [Lote 200/937] Perda Crítico: -0.3607 | Perda Gerador: -0.7973
# [Época 038] [Lote 300/937] Perda Crítico: -0.1447 | Perda Gerador: -0.1962
# [Época 038] [Lote 400/937] Perda Crítico: -0.2582 | Perda Gerador: -0.0991
# [Época 038] [Lote 500/937] Perda Crítico: -0.1623 | Perda Gerador: 1.1753
# [Época 038] [Lote 600/937] Perda Crítico: -0.0626 | Perda Gerador: 1.5156
# [Época 038] [Lote 700/937] Perda Crítico: -0.0805 | Perda Gerador: 1.8678
# [Época 038] [Lote 800/937] Perda Crítico: -0.1700 | Perda Gerador: 0.9530
# [Época 038] [Lote 900/937] Perda Crítico: -1.1695 | Perda Gerador: 1.4736
# [Época 038] [Lote 936/937] Perda Crítico: -0.0741 | Perda Gerador: -0.6976
# [Época 039] [Lote 000/937] Perda Crítico: 0.2278 | Perda Gerador: -0.4619
# [Época 039] [Lote 100/937] Perda Crítico: -0.2801 | Perda Gerador: 4.1495
# [Época 039] [Lote 200/937] Perda Crítico: -0.1168 | Perda Gerador: 0.1518
# [Época 039] [Lote 300/937] Perda Crítico: -0.2063 | Perda Gerador: 1.7734
# [Época 039] [Lote 400/937] Perda Crítico: -0.2210 | Perda Gerador: 1.8041
# [Época 039] [Lote 500/937] Perda Crítico: -0.6048 | Perda Gerador: 5.2659
# [Época 039] [Lote 600/937] Perda Crítico: -0.1346 | Perda Gerador: 0.1252
# [Época 039] [Lote 700/937] Perda Crítico: -0.0723 | Perda Gerador: 1.2823
# [Época 039] [Lote 800/937] Perda Crítico: 0.0448 | Perda Gerador: 1.3648
# [Época 039] [Lote 900/937] Perda Crítico: -0.0964 | Perda Gerador: 1.8753
# [Época 039] [Lote 936/937] Perda Crítico: -0.1094 | Perda Gerador: 1.3251
# [Época 040] [Lote 000/937] Perda Crítico: -0.1099 | Perda Gerador: 1.6700
# [Época 040] [Lote 100/937] Perda Crítico: 0.2431 | Perda Gerador: 0.4067
# [Época 040] [Lote 200/937] Perda Crítico: 0.1807 | Perda Gerador: -0.4744
# [Época 040] [Lote 300/937] Perda Crítico: -0.1760 | Perda Gerador: 0.1499
# [Época 040] [Lote 400/937] Perda Crítico: 0.1516 | Perda Gerador: 0.8507
# [Época 040] [Lote 500/937] Perda Crítico: -0.1725 | Perda Gerador: 1.5080
# [Época 040] [Lote 600/937] Perda Crítico: 0.0325 | Perda Gerador: -0.1156
# [Época 040] [Lote 700/937] Perda Crítico: -0.2925 | Perda Gerador: 1.8283
# [Época 040] [Lote 800/937] Perda Crítico: -0.3283 | Perda Gerador: -0.9456
# [Época 040] [Lote 900/937] Perda Crítico: -0.3956 | Perda Gerador: 5.2218
# [Época 040] [Lote 936/937] Perda Crítico: -0.1400 | Perda Gerador: -0.5523
# [Época 041] [Lote 000/937] Perda Crítico: -0.0230 | Perda Gerador: -0.9597
# [Época 041] [Lote 100/937] Perda Crítico: -0.0134 | Perda Gerador: 1.0302
# [Época 041] [Lote 200/937] Perda Crítico: -0.2672 | Perda Gerador: 3.7906
# [Época 041] [Lote 300/937] Perda Crítico: -0.0452 | Perda Gerador: 7.0004
# [Época 041] [Lote 400/937] Perda Crítico: -0.0662 | Perda Gerador: 1.7531
# [Época 041] [Lote 500/937] Perda Crítico: -0.0511 | Perda Gerador: 3.3578
# [Época 041] [Lote 600/937] Perda Crítico: 0.2324 | Perda Gerador: 1.9046
# [Época 041] [Lote 700/937] Perda Crítico: 0.1880 | Perda Gerador: 0.6390
# [Época 041] [Lote 800/937] Perda Crítico: 0.2617 | Perda Gerador: -0.5801
# [Época 041] [Lote 900/937] Perda Crítico: -0.1969 | Perda Gerador: 1.9553
# [Época 041] [Lote 936/937] Perda Crítico: -0.1493 | Perda Gerador: 1.5428
# [Época 042] [Lote 000/937] Perda Crítico: -0.0358 | Perda Gerador: 1.6301
# [Época 042] [Lote 100/937] Perda Crítico: 0.1629 | Perda Gerador: 3.5467
# [Época 042] [Lote 200/937] Perda Crítico: -0.0960 | Perda Gerador: -1.0818
# [Época 042] [Lote 300/937] Perda Crítico: -0.1097 | Perda Gerador: 4.3226
# [Época 042] [Lote 400/937] Perda Crítico: -0.0244 | Perda Gerador: 0.9214
# [Época 042] [Lote 500/937] Perda Crítico: -0.1124 | Perda Gerador: 1.1960
# [Época 042] [Lote 600/937] Perda Crítico: 0.5068 | Perda Gerador: 0.7550
# [Época 042] [Lote 700/937] Perda Crítico: -0.4922 | Perda Gerador: 0.3197
# [Época 042] [Lote 800/937] Perda Crítico: -0.1764 | Perda Gerador: -0.2275
# [Época 042] [Lote 900/937] Perda Crítico: 0.4671 | Perda Gerador: 2.1298
# [Época 042] [Lote 936/937] Perda Crítico: 0.2393 | Perda Gerador: -0.2709
# [Época 043] [Lote 000/937] Perda Crítico: -0.0548 | Perda Gerador: -1.1522
# [Época 043] [Lote 100/937] Perda Crítico: -0.3883 | Perda Gerador: 3.2819
# [Época 043] [Lote 200/937] Perda Crítico: 0.1457 | Perda Gerador: -1.1467
# [Época 043] [Lote 300/937] Perda Crítico: -0.4485 | Perda Gerador: 3.3161
# [Época 043] [Lote 400/937] Perda Crítico: 0.1540 | Perda Gerador: 3.4691
# [Época 043] [Lote 500/937] Perda Crítico: 0.7213 | Perda Gerador: 4.3133
# [Época 043] [Lote 600/937] Perda Crítico: -0.1801 | Perda Gerador: 0.0668
# [Época 043] [Lote 700/937] Perda Crítico: 0.6214 | Perda Gerador: -1.1720
# [Época 043] [Lote 800/937] Perda Crítico: 0.2756 | Perda Gerador: -1.3625
# [Época 043] [Lote 900/937] Perda Crítico: -0.0590 | Perda Gerador: 1.7889
# [Época 043] [Lote 936/937] Perda Crítico: 0.6251 | Perda Gerador: 3.3888
# [Época 044] [Lote 000/937] Perda Crítico: 0.0944 | Perda Gerador: 3.4626
# [Época 044] [Lote 100/937] Perda Crítico: -0.5560 | Perda Gerador: -2.1146
# [Época 044] [Lote 200/937] Perda Crítico: -0.6937 | Perda Gerador: -0.1859
# [Época 044] [Lote 300/937] Perda Crítico: -0.9436 | Perda Gerador: 5.8352
# [Época 044] [Lote 400/937] Perda Crítico: -0.7165 | Perda Gerador: 4.8617
# [Época 044] [Lote 500/937] Perda Crítico: -0.7313 | Perda Gerador: 0.3911
# [Época 044] [Lote 600/937] Perda Crítico: 0.0486 | Perda Gerador: -0.5135
# [Época 044] [Lote 700/937] Perda Crítico: -1.0368 | Perda Gerador: 9.0455
# [Época 044] [Lote 800/937] Perda Crítico: -0.1031 | Perda Gerador: -0.3957
# [Época 044] [Lote 900/937] Perda Crítico: 0.0377 | Perda Gerador: 3.6528
# [Época 044] [Lote 936/937] Perda Crítico: -1.4696 | Perda Gerador: -1.5693
# [Época 045] [Lote 000/937] Perda Crítico: -0.8552 | Perda Gerador: -1.6530
# [Época 045] [Lote 100/937] Perda Crítico: -0.4147 | Perda Gerador: 0.8920
# [Época 045] [Lote 200/937] Perda Crítico: -0.1421 | Perda Gerador: 0.8393
# [Época 045] [Lote 300/937] Perda Crítico: -0.4975 | Perda Gerador: 0.0660
# [Época 045] [Lote 400/937] Perda Crítico: -0.0599 | Perda Gerador: 4.2151
# [Época 045] [Lote 500/937] Perda Crítico: -0.2087 | Perda Gerador: -2.3621
# [Época 045] [Lote 600/937] Perda Crítico: -0.0112 | Perda Gerador: 2.0630
# [Época 045] [Lote 700/937] Perda Crítico: 0.0539 | Perda Gerador: 2.0915
# [Época 045] [Lote 800/937] Perda Crítico: -0.0916 | Perda Gerador: 0.9519
# [Época 045] [Lote 900/937] Perda Crítico: 0.0512 | Perda Gerador: 0.5699
# [Época 045] [Lote 936/937] Perda Crítico: -0.4957 | Perda Gerador: 8.4431
# [Época 046] [Lote 000/937] Perda Crítico: 0.9619 | Perda Gerador: 6.4781
# [Época 046] [Lote 100/937] Perda Crítico: 0.1404 | Perda Gerador: 0.9983
# [Época 046] [Lote 200/937] Perda Crítico: -2.0737 | Perda Gerador: 10.0917
# [Época 046] [Lote 300/937] Perda Crítico: -0.0314 | Perda Gerador: 1.4662
# [Época 046] [Lote 400/937] Perda Crítico: -0.2542 | Perda Gerador: 6.2320
# [Época 046] [Lote 500/937] Perda Crítico: -0.0366 | Perda Gerador: 1.2293
# [Época 046] [Lote 600/937] Perda Crítico: 0.0006 | Perda Gerador: -1.9340
# [Época 046] [Lote 700/937] Perda Crítico: -0.2044 | Perda Gerador: 4.1905
# [Época 046] [Lote 800/937] Perda Crítico: -0.0998 | Perda Gerador: 1.6927
# [Época 046] [Lote 900/937] Perda Crítico: 0.2531 | Perda Gerador: -0.1880
# [Época 046] [Lote 936/937] Perda Crítico: 1.0843 | Perda Gerador: 4.1704
# [Época 047] [Lote 000/937] Perda Crítico: 0.4922 | Perda Gerador: 2.8774
# [Época 047] [Lote 100/937] Perda Crítico: -0.2179 | Perda Gerador: -1.1715
# [Época 047] [Lote 200/937] Perda Crítico: -0.0388 | Perda Gerador: 4.4361
# [Época 047] [Lote 300/937] Perda Crítico: 0.1303 | Perda Gerador: -2.0036
# [Época 047] [Lote 400/937] Perda Crítico: -0.1032 | Perda Gerador: -0.4869
# [Época 047] [Lote 500/937] Perda Crítico: -0.0244 | Perda Gerador: 0.0400
# [Época 047] [Lote 600/937] Perda Crítico: 0.0061 | Perda Gerador: 6.8902
# [Época 047] [Lote 700/937] Perda Crítico: -0.0857 | Perda Gerador: -0.1415
# [Época 047] [Lote 800/937] Perda Crítico: -0.1435 | Perda Gerador: 2.2411
# [Época 047] [Lote 900/937] Perda Crítico: -0.3430 | Perda Gerador: 2.4630
# [Época 047] [Lote 936/937] Perda Crítico: 0.1125 | Perda Gerador: 0.1773
# [Época 048] [Lote 000/937] Perda Crítico: -0.1146 | Perda Gerador: 0.2444
# [Época 048] [Lote 100/937] Perda Crítico: 0.0142 | Perda Gerador: 4.7092
# [Época 048] [Lote 200/937] Perda Crítico: -0.0663 | Perda Gerador: 1.8768
# [Época 048] [Lote 300/937] Perda Crítico: -1.2134 | Perda Gerador: 9.7134
# [Época 048] [Lote 400/937] Perda Crítico: -0.4125 | Perda Gerador: 3.4477
# [Época 048] [Lote 500/937] Perda Crítico: -1.0169 | Perda Gerador: -3.4794
# [Época 048] [Lote 600/937] Perda Crítico: 0.1474 | Perda Gerador: -3.1383
# [Época 048] [Lote 700/937] Perda Crítico: 0.0975 | Perda Gerador: 11.4249
# [Época 048] [Lote 800/937] Perda Crítico: -0.1834 | Perda Gerador: -0.8149
# [Época 048] [Lote 900/937] Perda Crítico: -0.0726 | Perda Gerador: -1.8408
# [Época 048] [Lote 936/937] Perda Crítico: 0.5541 | Perda Gerador: -2.0113
# [Época 049] [Lote 000/937] Perda Crítico: -0.1152 | Perda Gerador: -1.7147
# [Época 049] [Lote 100/937] Perda Crítico: 0.1140 | Perda Gerador: -3.2342
# [Época 049] [Lote 200/937] Perda Crítico: -0.1586 | Perda Gerador: -2.5354
# [Época 049] [Lote 300/937] Perda Crítico: -0.1371 | Perda Gerador: 4.3164
# [Época 049] [Lote 400/937] Perda Crítico: -0.7621 | Perda Gerador: 7.7758
# [Época 049] [Lote 500/937] Perda Crítico: 0.0154 | Perda Gerador: -2.5610
# [Época 049] [Lote 600/937] Perda Crítico: -0.3020 | Perda Gerador: 6.7564
# [Época 049] [Lote 700/937] Perda Crítico: -0.3298 | Perda Gerador: 8.2704
# [Época 049] [Lote 800/937] Perda Crítico: 0.0880 | Perda Gerador: 3.9611
# [Época 049] [Lote 900/937] Perda Crítico: -0.2365 | Perda Gerador: -1.4784
# [Época 049] [Lote 936/937] Perda Crítico: -1.2251 | Perda Gerador: 10.8635
# [Época 050] [Lote 000/937] Perda Crítico: 0.1158 | Perda Gerador: 10.1626
# [Época 050] [Lote 100/937] Perda Crítico: 1.4518 | Perda Gerador: -3.7096
# [Época 050] [Lote 200/937] Perda Crítico: 0.0791 | Perda Gerador: 0.1949
# [Época 050] [Lote 300/937] Perda Crítico: -1.1060 | Perda Gerador: 5.4119
# [Época 050] [Lote 400/937] Perda Crítico: 0.1592 | Perda Gerador: -1.9566
# [Época 050] [Lote 500/937] Perda Crítico: -0.1374 | Perda Gerador: -3.9480
# [Época 050] [Lote 600/937] Perda Crítico: -0.1476 | Perda Gerador: 2.9735
# [Época 050] [Lote 700/937] Perda Crítico: 0.0740 | Perda Gerador: -0.9464
# [Época 050] [Lote 800/937] Perda Crítico: 0.1159 | Perda Gerador: -2.5349
# [Época 050] [Lote 900/937] Perda Crítico: 0.2492 | Perda Gerador: 0.6928
# [Época 050] [Lote 936/937] Perda Crítico: -0.5963 | Perda Gerador: 3.3355
# [Época 051] [Lote 000/937] Perda Crítico: -0.0530 | Perda Gerador: 2.5138
# [Época 051] [Lote 100/937] Perda Crítico: -0.2613 | Perda Gerador: 0.4512
# [Época 051] [Lote 200/937] Perda Crítico: 0.0608 | Perda Gerador: 2.3030
# [Época 051] [Lote 300/937] Perda Crítico: -0.0699 | Perda Gerador: 0.8516
# [Época 051] [Lote 400/937] Perda Crítico: 0.1072 | Perda Gerador: 1.4860
# [Época 051] [Lote 500/937] Perda Crítico: -0.3987 | Perda Gerador: -3.0085
# [Época 051] [Lote 600/937] Perda Crítico: 0.2856 | Perda Gerador: 2.9364
# [Época 051] [Lote 700/937] Perda Crítico: 0.6596 | Perda Gerador: 6.0932
# [Época 051] [Lote 800/937] Perda Crítico: -0.1552 | Perda Gerador: 0.1767
# [Época 051] [Lote 900/937] Perda Crítico: -0.5574 | Perda Gerador: 3.5693
# [Época 051] [Lote 936/937] Perda Crítico: 0.1776 | Perda Gerador: -1.4131
# [Época 052] [Lote 000/937] Perda Crítico: 0.3718 | Perda Gerador: -0.9422
# [Época 052] [Lote 100/937] Perda Crítico: -0.4323 | Perda Gerador: -1.8780
# [Época 052] [Lote 200/937] Perda Crítico: 0.1414 | Perda Gerador: 6.5253
# [Época 052] [Lote 300/937] Perda Crítico: -0.3045 | Perda Gerador: 3.1144
# [Época 052] [Lote 400/937] Perda Crítico: -0.0973 | Perda Gerador: 3.5645
# [Época 052] [Lote 500/937] Perda Crítico: -0.0773 | Perda Gerador: -0.3361
# [Época 052] [Lote 600/937] Perda Crítico: -0.0821 | Perda Gerador: -2.3708
# [Época 052] [Lote 700/937] Perda Crítico: -0.7423 | Perda Gerador: 7.2709
# [Época 052] [Lote 800/937] Perda Crítico: -0.0903 | Perda Gerador: -1.6826
# [Época 052] [Lote 900/937] Perda Crítico: -0.0058 | Perda Gerador: -2.7278
# [Época 052] [Lote 936/937] Perda Crítico: -0.2177 | Perda Gerador: 3.7120
# [Época 053] [Lote 000/937] Perda Crítico: -0.1709 | Perda Gerador: 3.2604
# [Época 053] [Lote 100/937] Perda Crítico: -0.4244 | Perda Gerador: -0.9151
# [Época 053] [Lote 200/937] Perda Crítico: -0.0066 | Perda Gerador: 1.9045
# [Época 053] [Lote 300/937] Perda Crítico: 0.1106 | Perda Gerador: -1.6400
# [Época 053] [Lote 400/937] Perda Crítico: 0.0142 | Perda Gerador: -0.7215
# [Época 053] [Lote 500/937] Perda Crítico: -0.1272 | Perda Gerador: -3.5603
# [Época 053] [Lote 600/937] Perda Crítico: 0.2531 | Perda Gerador: 3.3778
# [Época 053] [Lote 700/937] Perda Crítico: 0.6369 | Perda Gerador: -1.5534
# [Época 053] [Lote 800/937] Perda Crítico: -0.3596 | Perda Gerador: -1.0862
# [Época 053] [Lote 900/937] Perda Crítico: -0.5513 | Perda Gerador: -2.0247
# [Época 053] [Lote 936/937] Perda Crítico: -1.4896 | Perda Gerador: 5.2297
# [Época 054] [Lote 000/937] Perda Crítico: 0.2672 | Perda Gerador: 5.5410
# [Época 054] [Lote 100/937] Perda Crítico: -0.2915 | Perda Gerador: 4.0373
# [Época 054] [Lote 200/937] Perda Crítico: -0.6264 | Perda Gerador: 7.3744
# [Época 054] [Lote 300/937] Perda Crítico: 0.1031 | Perda Gerador: 9.5524
# [Época 054] [Lote 400/937] Perda Crítico: -0.0311 | Perda Gerador: 0.5396
# [Época 054] [Lote 500/937] Perda Crítico: -0.5235 | Perda Gerador: 4.9999
# [Época 054] [Lote 600/937] Perda Crítico: -0.3371 | Perda Gerador: 3.3358
# [Época 054] [Lote 700/937] Perda Crítico: 0.1924 | Perda Gerador: 0.3473
# [Época 054] [Lote 800/937] Perda Crítico: -0.0619 | Perda Gerador: 1.4778
# [Época 054] [Lote 900/937] Perda Crítico: -0.1092 | Perda Gerador: -1.2786
# [Época 054] [Lote 936/937] Perda Crítico: -0.3624 | Perda Gerador: 2.6585
# [Época 055] [Lote 000/937] Perda Crítico: -0.0343 | Perda Gerador: 1.5376
# [Época 055] [Lote 100/937] Perda Crítico: 0.0614 | Perda Gerador: -0.2036
# [Época 055] [Lote 200/937] Perda Crítico: 0.0302 | Perda Gerador: 0.4000
# [Época 055] [Lote 300/937] Perda Crítico: -0.9776 | Perda Gerador: -1.4762
# [Época 055] [Lote 400/937] Perda Crítico: 0.2545 | Perda Gerador: -0.0742
# [Época 055] [Lote 500/937] Perda Crítico: -0.3428 | Perda Gerador: -0.5103
# [Época 055] [Lote 600/937] Perda Crítico: -0.0229 | Perda Gerador: 8.7738
# [Época 055] [Lote 700/937] Perda Crítico: 0.2380 | Perda Gerador: 6.4164
# [Época 055] [Lote 800/937] Perda Crítico: -0.0626 | Perda Gerador: -0.3092
# [Época 055] [Lote 900/937] Perda Crítico: 0.7037 | Perda Gerador: 7.6412
# [Época 055] [Lote 936/937] Perda Crítico: -0.2361 | Perda Gerador: 3.9472
# [Época 056] [Lote 000/937] Perda Crítico: 0.4843 | Perda Gerador: 2.0983
# [Época 056] [Lote 100/937] Perda Crítico: 0.2066 | Perda Gerador: 3.9525
# [Época 056] [Lote 200/937] Perda Crítico: 0.0057 | Perda Gerador: -1.9293
# [Época 056] [Lote 300/937] Perda Crítico: -0.1888 | Perda Gerador: -0.0821
# [Época 056] [Lote 400/937] Perda Crítico: -0.0275 | Perda Gerador: 3.2753
# [Época 056] [Lote 500/937] Perda Crítico: 0.1456 | Perda Gerador: -0.9196
# [Época 056] [Lote 600/937] Perda Crítico: 0.1349 | Perda Gerador: 6.6752
# [Época 056] [Lote 700/937] Perda Crítico: 0.1611 | Perda Gerador: 4.0704
# [Época 056] [Lote 800/937] Perda Crítico: -0.6749 | Perda Gerador: 2.4194
# [Época 056] [Lote 900/937] Perda Crítico: 0.6169 | Perda Gerador: -1.6716
# [Época 056] [Lote 936/937] Perda Crítico: 0.6366 | Perda Gerador: 6.1776
# [Época 057] [Lote 000/937] Perda Crítico: -0.6026 | Perda Gerador: 6.8233
# [Época 057] [Lote 100/937] Perda Crítico: 0.0417 | Perda Gerador: -1.7223
# [Época 057] [Lote 200/937] Perda Crítico: 0.3545 | Perda Gerador: -3.4727
# [Época 057] [Lote 300/937] Perda Crítico: 0.0875 | Perda Gerador: 0.4149
# [Época 057] [Lote 400/937] Perda Crítico: -0.2805 | Perda Gerador: 1.9638
# [Época 057] [Lote 500/937] Perda Crítico: -0.0868 | Perda Gerador: 2.9390
# [Época 057] [Lote 600/937] Perda Crítico: -0.2849 | Perda Gerador: -2.1934
# [Época 057] [Lote 700/937] Perda Crítico: -0.0510 | Perda Gerador: 6.2472
# [Época 057] [Lote 800/937] Perda Crítico: -0.5451 | Perda Gerador: -1.6298
# [Época 057] [Lote 900/937] Perda Crítico: 0.0786 | Perda Gerador: 2.3991
# [Época 057] [Lote 936/937] Perda Crítico: -0.0977 | Perda Gerador: 0.2100
# [Época 058] [Lote 000/937] Perda Crítico: -0.2984 | Perda Gerador: -0.0154
# [Época 058] [Lote 100/937] Perda Crítico: 0.7334 | Perda Gerador: -1.5857
# [Época 058] [Lote 200/937] Perda Crítico: 0.5733 | Perda Gerador: -2.0088
# [Época 058] [Lote 300/937] Perda Crítico: -0.1122 | Perda Gerador: -1.7006
# [Época 058] [Lote 400/937] Perda Crítico: -0.2522 | Perda Gerador: 1.9079
# [Época 058] [Lote 500/937] Perda Crítico: 0.4297 | Perda Gerador: 3.3209
# [Época 058] [Lote 600/937] Perda Crítico: -0.3417 | Perda Gerador: -1.9346
# [Época 058] [Lote 700/937] Perda Crítico: -0.2241 | Perda Gerador: -3.5920
# [Época 058] [Lote 800/937] Perda Crítico: 0.2549 | Perda Gerador: 2.2791
# [Época 058] [Lote 900/937] Perda Crítico: -0.6074 | Perda Gerador: -1.0083
# [Época 058] [Lote 936/937] Perda Crítico: 0.7051 | Perda Gerador: -1.0249
# [Época 059] [Lote 000/937] Perda Crítico: -0.0930 | Perda Gerador: -1.6631
# [Época 059] [Lote 100/937] Perda Crítico: 0.3206 | Perda Gerador: -3.6609
# [Época 059] [Lote 200/937] Perda Crítico: 0.2133 | Perda Gerador: 0.7736
# [Época 059] [Lote 300/937] Perda Crítico: -0.0482 | Perda Gerador: 3.2077
# [Época 059] [Lote 400/937] Perda Crítico: -0.4043 | Perda Gerador: -0.5624
# [Época 059] [Lote 500/937] Perda Crítico: -0.2203 | Perda Gerador: -0.7566
# [Época 059] [Lote 600/937] Perda Crítico: 0.0032 | Perda Gerador: 2.2199
# [Época 059] [Lote 700/937] Perda Crítico: 0.1060 | Perda Gerador: 2.5651
# [Época 059] [Lote 800/937] Perda Crítico: -1.0845 | Perda Gerador: -2.3907
# [Época 059] [Lote 900/937] Perda Crítico: -0.9491 | Perda Gerador: 5.4091
# [Época 059] [Lote 936/937] Perda Crítico: -0.0945 | Perda Gerador: 1.4055
# ...
# [Época 081] [Lote 400/937] Perda Crítico: -0.1510 | Perda Gerador: 3.7778
# [Época 081] [Lote 500/937] Perda Crítico: -0.0224 | Perda Gerador: -2.4342
# [Época 081] [Lote 600/937] Perda Crítico: 0.0194 | Perda Gerador: 4.2461
# [Época 081] [Lote 700/937] Perda Crítico: -0.0843 | Perda Gerador: 0.9535
# [Época 081] [Lote 800/937] Perda Crítico: 0.7917 | Perda Gerador: -0.2944
# [Época 081] [Lote 900/937] Perda Crítico: -0.0480 | Perda Gerador: -2.1051
# [Época 081] [Lote 936/937] Perda Crítico: -0.4850 | Perda Gerador: 5.7944
# [Época 082] [Lote 000/937] Perda Crítico: -0.6758 | Perda Gerador: 7.3420
# [Época 082] [Lote 100/937] Perda Crítico: -0.0191 | Perda Gerador: -2.7066
# [Época 082] [Lote 200/937] Perda Crítico: 0.2604 | Perda Gerador: -2.9132
# [Época 082] [Lote 300/937] Perda Crítico: -0.5004 | Perda Gerador: -4.7118
# [Época 082] [Lote 400/937] Perda Crítico: -0.0882 | Perda Gerador: -2.2616
# [Época 082] [Lote 500/937] Perda Crítico: -1.3437 | Perda Gerador: -6.3117
# [Época 082] [Lote 600/937] Perda Crítico: -0.2737 | Perda Gerador: 0.6279
# [Época 082] [Lote 700/937] Perda Crítico: -0.2625 | Perda Gerador: 1.8993
# [Época 082] [Lote 800/937] Perda Crítico: -1.0449 | Perda Gerador: 6.0337
# [Época 082] [Lote 900/937] Perda Crítico: -0.5163 | Perda Gerador: -5.2014
# [Época 082] [Lote 936/937] Perda Crítico: -0.1578 | Perda Gerador: 5.4335
# [Época 083] [Lote 000/937] Perda Crítico: -0.1781 | Perda Gerador: 4.5089
# [Época 083] [Lote 100/937] Perda Crítico: -1.0645 | Perda Gerador: 8.8003
# [Época 083] [Lote 200/937] Perda Crítico: 0.3497 | Perda Gerador: 2.5646
# [Época 083] [Lote 300/937] Perda Crítico: 0.1067 | Perda Gerador: -5.5457
# [Época 083] [Lote 400/937] Perda Crítico: -0.1375 | Perda Gerador: -2.7529
# [Época 083] [Lote 500/937] Perda Crítico: 0.4410 | Perda Gerador: 5.0984
# [Época 083] [Lote 600/937] Perda Crítico: -1.9191 | Perda Gerador: 9.4241
# [Época 083] [Lote 700/937] Perda Crítico: -0.0468 | Perda Gerador: -0.1256
# [Época 083] [Lote 800/937] Perda Crítico: -0.1418 | Perda Gerador: 0.6729
# [Época 083] [Lote 900/937] Perda Crítico: 0.8232 | Perda Gerador: 5.0937
# [Época 083] [Lote 936/937] Perda Crítico: 0.4564 | Perda Gerador: 5.0268
# [Época 084] [Lote 000/937] Perda Crítico: 0.3226 | Perda Gerador: 3.8167
# [Época 084] [Lote 100/937] Perda Crítico: 0.3707 | Perda Gerador: 0.2401
# [Época 084] [Lote 200/937] Perda Crítico: -0.7029 | Perda Gerador: -2.7376
# [Época 084] [Lote 300/937] Perda Crítico: -0.5990 | Perda Gerador: 3.9488
# [Época 084] [Lote 400/937] Perda Crítico: -0.0190 | Perda Gerador: 1.5772
# [Época 084] [Lote 500/937] Perda Crítico: -0.2776 | Perda Gerador: 4.8521
# [Época 084] [Lote 600/937] Perda Crítico: 0.4938 | Perda Gerador: 4.3072
# [Época 084] [Lote 700/937] Perda Crítico: -0.1393 | Perda Gerador: 2.6951
# [Época 084] [Lote 800/937] Perda Crítico: -0.1366 | Perda Gerador: -2.3249
# [Época 084] [Lote 900/937] Perda Crítico: -0.3862 | Perda Gerador: -1.8733
# [Época 084] [Lote 936/937] Perda Crítico: -0.2821 | Perda Gerador: 1.3424
# [Época 085] [Lote 000/937] Perda Crítico: -0.9936 | Perda Gerador: 3.9366
# [Época 085] [Lote 100/937] Perda Crítico: 0.0600 | Perda Gerador: 1.8809
# [Época 085] [Lote 200/937] Perda Crítico: -0.3143 | Perda Gerador: 2.3099
# [Época 085] [Lote 300/937] Perda Crítico: -0.3617 | Perda Gerador: 3.7026
# [Época 085] [Lote 400/937] Perda Crítico: -0.1652 | Perda Gerador: -1.5440
# [Época 085] [Lote 500/937] Perda Crítico: 0.0059 | Perda Gerador: -3.7109
# [Época 085] [Lote 600/937] Perda Crítico: -0.2601 | Perda Gerador: 3.0613
# [Época 085] [Lote 700/937] Perda Crítico: 0.1743 | Perda Gerador: -2.0584
# [Época 085] [Lote 800/937] Perda Crítico: 0.0671 | Perda Gerador: 4.6821
# [Época 085] [Lote 900/937] Perda Crítico: -0.7238 | Perda Gerador: -0.1492
# [Época 085] [Lote 936/937] Perda Crítico: 0.5259 | Perda Gerador: -1.9835
# [Época 086] [Lote 000/937] Perda Crítico: -0.7079 | Perda Gerador: -2.8115
# [Época 086] [Lote 100/937] Perda Crítico: -0.2103 | Perda Gerador: -0.1777
# [Época 086] [Lote 200/937] Perda Crítico: -0.0796 | Perda Gerador: 0.4056
# [Época 086] [Lote 300/937] Perda Crítico: 0.6645 | Perda Gerador: -1.4029
# [Época 086] [Lote 400/937] Perda Crítico: 0.0013 | Perda Gerador: 2.2317
# [Época 086] [Lote 500/937] Perda Crítico: -0.2477 | Perda Gerador: 2.4887
# [Época 086] [Lote 600/937] Perda Crítico: 0.6407 | Perda Gerador: 2.0361
# [Época 086] [Lote 700/937] Perda Crítico: -0.0155 | Perda Gerador: -0.4253
# [Época 086] [Lote 800/937] Perda Crítico: 0.0783 | Perda Gerador: 1.4042
# [Época 086] [Lote 900/937] Perda Crítico: -0.3596 | Perda Gerador: 4.2939
# [Época 086] [Lote 936/937] Perda Crítico: -0.1533 | Perda Gerador: 1.2686
# [Época 087] [Lote 000/937] Perda Crítico: -0.0057 | Perda Gerador: 2.3726
# [Época 087] [Lote 100/937] Perda Crítico: -0.1359 | Perda Gerador: 3.8697
# [Época 087] [Lote 200/937] Perda Crítico: -0.1406 | Perda Gerador: 2.2175
# [Época 087] [Lote 300/937] Perda Crítico: -0.1308 | Perda Gerador: 0.3468
# [Época 087] [Lote 400/937] Perda Crítico: 0.0730 | Perda Gerador: 0.0560
# [Época 087] [Lote 500/937] Perda Crítico: -0.0176 | Perda Gerador: 1.9202
# [Época 087] [Lote 600/937] Perda Crítico: -0.0106 | Perda Gerador: 1.8142
# [Época 087] [Lote 700/937] Perda Crítico: 0.4229 | Perda Gerador: 7.7288
# [Época 087] [Lote 800/937] Perda Crítico: -0.7925 | Perda Gerador: 8.4039
# [Época 087] [Lote 900/937] Perda Crítico: -1.5217 | Perda Gerador: 10.6626
# [Época 087] [Lote 936/937] Perda Crítico: -0.3935 | Perda Gerador: 2.9930
# [Época 088] [Lote 000/937] Perda Crítico: -0.7838 | Perda Gerador: 4.7454
# [Época 088] [Lote 100/937] Perda Crítico: -0.5561 | Perda Gerador: 6.1793
# [Época 088] [Lote 200/937] Perda Crítico: -0.5000 | Perda Gerador: -1.6042
# [Época 088] [Lote 300/937] Perda Crítico: -1.9896 | Perda Gerador: 9.1892
# [Época 088] [Lote 400/937] Perda Crítico: -0.1942 | Perda Gerador: 5.0939
# [Época 088] [Lote 500/937] Perda Crítico: -0.0346 | Perda Gerador: 3.5774
# [Época 088] [Lote 600/937] Perda Crítico: 0.2210 | Perda Gerador: 0.2352
# [Época 088] [Lote 700/937] Perda Crítico: 0.0827 | Perda Gerador: 1.9318
# [Época 088] [Lote 800/937] Perda Crítico: -0.4038 | Perda Gerador: 1.2842
# [Época 088] [Lote 900/937] Perda Crítico: -1.0872 | Perda Gerador: 5.2448
# [Época 088] [Lote 936/937] Perda Crítico: 0.4446 | Perda Gerador: 7.2616
# [Época 089] [Lote 000/937] Perda Crítico: 0.6378 | Perda Gerador: 5.5911
# [Época 089] [Lote 100/937] Perda Crítico: -0.8468 | Perda Gerador: 4.0318
# [Época 089] [Lote 200/937] Perda Crítico: 0.0337 | Perda Gerador: 2.1087
# [Época 089] [Lote 300/937] Perda Crítico: -0.2915 | Perda Gerador: -4.5267
# [Época 089] [Lote 400/937] Perda Crítico: -0.3064 | Perda Gerador: 2.7244
# [Época 089] [Lote 500/937] Perda Crítico: -2.0082 | Perda Gerador: 10.2175
# [Época 089] [Lote 600/937] Perda Crítico: 0.3596 | Perda Gerador: 8.2808
# [Época 089] [Lote 700/937] Perda Crítico: -0.2433 | Perda Gerador: 2.9140
# [Época 089] [Lote 800/937] Perda Crítico: -0.1885 | Perda Gerador: -0.4870
# [Época 089] [Lote 900/937] Perda Crítico: -0.0909 | Perda Gerador: -1.8777
# [Época 089] [Lote 936/937] Perda Crítico: 0.3369 | Perda Gerador: 0.5457
# [Época 090] [Lote 000/937] Perda Crítico: -0.2163 | Perda Gerador: 3.9689
# [Época 090] [Lote 100/937] Perda Crítico: 0.0071 | Perda Gerador: 3.1874
# [Época 090] [Lote 200/937] Perda Crítico: -0.1954 | Perda Gerador: -0.8367
# [Época 090] [Lote 300/937] Perda Crítico: 1.1093 | Perda Gerador: 6.9935
# [Época 090] [Lote 400/937] Perda Crítico: 0.0670 | Perda Gerador: -1.8379
# [Época 090] [Lote 500/937] Perda Crítico: -0.1264 | Perda Gerador: -0.0397
# [Época 090] [Lote 600/937] Perda Crítico: 0.0785 | Perda Gerador: 5.1266
# [Época 090] [Lote 700/937] Perda Crítico: -0.1751 | Perda Gerador: 0.6224
# [Época 090] [Lote 800/937] Perda Crítico: -0.2113 | Perda Gerador: -1.6243
# [Época 090] [Lote 900/937] Perda Crítico: -0.8362 | Perda Gerador: 0.7001
# [Época 090] [Lote 936/937] Perda Crítico: -0.1094 | Perda Gerador: 3.7534
# [Época 091] [Lote 000/937] Perda Crítico: -0.0442 | Perda Gerador: 4.0954
# [Época 091] [Lote 100/937] Perda Crítico: 0.0206 | Perda Gerador: -2.6063
# [Época 091] [Lote 200/937] Perda Crítico: -3.1014 | Perda Gerador: 11.5992
# [Época 091] [Lote 300/937] Perda Crítico: -0.0935 | Perda Gerador: 5.5228
# [Época 091] [Lote 400/937] Perda Crítico: 0.0109 | Perda Gerador: 1.4507
# [Época 091] [Lote 500/937] Perda Crítico: 0.3949 | Perda Gerador: 0.6325
# [Época 091] [Lote 600/937] Perda Crítico: -0.0478 | Perda Gerador: 5.6538
# [Época 091] [Lote 700/937] Perda Crítico: 0.5749 | Perda Gerador: -2.0397
# [Época 091] [Lote 800/937] Perda Crítico: -0.1012 | Perda Gerador: 2.1824
# [Época 091] [Lote 900/937] Perda Crítico: 0.0706 | Perda Gerador: 1.9953
# [Época 091] [Lote 936/937] Perda Crítico: 0.0745 | Perda Gerador: -0.4650
# [Época 092] [Lote 000/937] Perda Crítico: 0.0214 | Perda Gerador: 0.0301
# [Época 092] [Lote 100/937] Perda Crítico: 1.0466 | Perda Gerador: -1.8026
# [Época 092] [Lote 200/937] Perda Crítico: -1.4320 | Perda Gerador: 8.4991
# [Época 092] [Lote 300/937] Perda Crítico: -0.1750 | Perda Gerador: 2.6248
# [Época 092] [Lote 400/937] Perda Crítico: 0.1717 | Perda Gerador: 8.5657
# [Época 092] [Lote 500/937] Perda Crítico: -0.4371 | Perda Gerador: -1.4320
# [Época 092] [Lote 600/937] Perda Crítico: -0.4952 | Perda Gerador: -1.0405
# [Época 092] [Lote 700/937] Perda Crítico: -0.5350 | Perda Gerador: -0.9547
# [Época 092] [Lote 800/937] Perda Crítico: -0.1876 | Perda Gerador: 3.2058
# [Época 092] [Lote 900/937] Perda Crítico: 0.1581 | Perda Gerador: 2.3739
# [Época 092] [Lote 936/937] Perda Crítico: 0.1763 | Perda Gerador: 0.8272
# [Época 093] [Lote 000/937] Perda Crítico: -0.4428 | Perda Gerador: 3.6843
# [Época 093] [Lote 100/937] Perda Crítico: 0.0266 | Perda Gerador: -0.5895
# [Época 093] [Lote 200/937] Perda Crítico: -0.2338 | Perda Gerador: -3.3452
# [Época 093] [Lote 300/937] Perda Crítico: -0.8855 | Perda Gerador: -0.2562
# [Época 093] [Lote 400/937] Perda Crítico: -0.7893 | Perda Gerador: -1.7976
# [Época 093] [Lote 500/937] Perda Crítico: -0.1529 | Perda Gerador: -0.3505
# [Época 093] [Lote 600/937] Perda Crítico: -0.0150 | Perda Gerador: 0.7027
# [Época 093] [Lote 700/937] Perda Crítico: 0.0309 | Perda Gerador: -0.5402
# [Época 093] [Lote 800/937] Perda Crítico: 0.4568 | Perda Gerador: -1.8435
# [Época 093] [Lote 900/937] Perda Crítico: -0.6046 | Perda Gerador: -3.2617
# [Época 093] [Lote 936/937] Perda Crítico: 0.7597 | Perda Gerador: -6.4840
# [Época 094] [Lote 000/937] Perda Crítico: 0.3232 | Perda Gerador: -5.6956
# [Época 094] [Lote 100/937] Perda Crítico: -0.8699 | Perda Gerador: -1.2310
# [Época 094] [Lote 200/937] Perda Crítico: -0.0942 | Perda Gerador: -0.3403
# [Época 094] [Lote 300/937] Perda Crítico: -1.0348 | Perda Gerador: -2.3684
# [Época 094] [Lote 400/937] Perda Crítico: -0.7221 | Perda Gerador: 4.0031
# [Época 094] [Lote 500/937] Perda Crítico: -0.0887 | Perda Gerador: -2.3365
# [Época 094] [Lote 600/937] Perda Crítico: 1.1989 | Perda Gerador: 3.9783
# [Época 094] [Lote 700/937] Perda Crítico: -0.0343 | Perda Gerador: 8.3485
# [Época 094] [Lote 800/937] Perda Crítico: 0.4272 | Perda Gerador: 5.8772
# [Época 094] [Lote 900/937] Perda Crítico: 1.0509 | Perda Gerador: 6.4540
# [Época 094] [Lote 936/937] Perda Crítico: 0.7894 | Perda Gerador: 8.3453
# [Época 095] [Lote 000/937] Perda Crítico: 1.7386 | Perda Gerador: 5.2873
# [Época 095] [Lote 100/937] Perda Crítico: -0.9573 | Perda Gerador: 7.9256
# [Época 095] [Lote 200/937] Perda Crítico: -0.1011 | Perda Gerador: 1.9193
# [Época 095] [Lote 300/937] Perda Crítico: -0.4695 | Perda Gerador: 3.3557
# [Época 095] [Lote 400/937] Perda Crítico: 0.4075 | Perda Gerador: 4.7317
# [Época 095] [Lote 500/937] Perda Crítico: -0.0660 | Perda Gerador: 1.9597
# [Época 095] [Lote 600/937] Perda Crítico: 0.2123 | Perda Gerador: -2.0096
# [Época 095] [Lote 700/937] Perda Crítico: -0.3754 | Perda Gerador: 5.7953
# [Época 095] [Lote 800/937] Perda Crítico: 0.0499 | Perda Gerador: -0.3437
# [Época 095] [Lote 900/937] Perda Crítico: -0.0934 | Perda Gerador: 1.6557
# [Época 095] [Lote 936/937] Perda Crítico: 0.2957 | Perda Gerador: -3.4807
# [Época 096] [Lote 000/937] Perda Crítico: -0.8529 | Perda Gerador: -3.9922
# [Época 096] [Lote 100/937] Perda Crítico: 0.0791 | Perda Gerador: -0.3064
# [Época 096] [Lote 200/937] Perda Crítico: -0.0149 | Perda Gerador: -1.3714
# [Época 096] [Lote 300/937] Perda Crítico: -0.2508 | Perda Gerador: 1.0662
# [Época 096] [Lote 400/937] Perda Crítico: -0.3289 | Perda Gerador: 0.9800
# [Época 096] [Lote 500/937] Perda Crítico: -0.1200 | Perda Gerador: -3.7388
# [Época 096] [Lote 600/937] Perda Crítico: -0.0324 | Perda Gerador: 2.2536
# [Época 096] [Lote 700/937] Perda Crítico: 0.0466 | Perda Gerador: 1.2683
# [Época 096] [Lote 800/937] Perda Crítico: -0.1492 | Perda Gerador: 5.3459
# [Época 096] [Lote 900/937] Perda Crítico: 0.3287 | Perda Gerador: 4.0611
# [Época 096] [Lote 936/937] Perda Crítico: -0.4297 | Perda Gerador: -1.8530
# [Época 097] [Lote 000/937] Perda Crítico: 0.0548 | Perda Gerador: -1.1518
# [Época 097] [Lote 100/937] Perda Crítico: 0.2193 | Perda Gerador: 8.1142
# [Época 097] [Lote 200/937] Perda Crítico: -0.0437 | Perda Gerador: -0.0363
# [Época 097] [Lote 300/937] Perda Crítico: -1.7009 | Perda Gerador: 4.9103
# [Época 097] [Lote 400/937] Perda Crítico: -0.4462 | Perda Gerador: 8.2446
# [Época 097] [Lote 500/937] Perda Crítico: -0.1360 | Perda Gerador: 1.9135
# [Época 097] [Lote 600/937] Perda Crítico: -0.0028 | Perda Gerador: 7.7408
# [Época 097] [Lote 700/937] Perda Crítico: 0.0061 | Perda Gerador: 5.8380
# [Época 097] [Lote 800/937] Perda Crítico: -0.1243 | Perda Gerador: 0.1816
# [Época 097] [Lote 900/937] Perda Crítico: -0.6433 | Perda Gerador: -3.7092
# [Época 097] [Lote 936/937] Perda Crítico: -0.5676 | Perda Gerador: -2.0296
# [Época 098] [Lote 000/937] Perda Crítico: -0.5450 | Perda Gerador: -2.9057
# [Época 098] [Lote 100/937] Perda Crítico: -0.1754 | Perda Gerador: 5.2925
# [Época 098] [Lote 200/937] Perda Crítico: -0.0704 | Perda Gerador: 6.2237
# [Época 098] [Lote 300/937] Perda Crítico: -0.3489 | Perda Gerador: -2.5867
# [Época 098] [Lote 400/937] Perda Crítico: -1.0302 | Perda Gerador: 4.3943
# [Época 098] [Lote 500/937] Perda Crítico: -0.3721 | Perda Gerador: -0.4503
# [Época 098] [Lote 600/937] Perda Crítico: -0.1462 | Perda Gerador: -1.5711
# [Época 098] [Lote 700/937] Perda Crítico: -0.0491 | Perda Gerador: 5.4127
# [Época 098] [Lote 800/937] Perda Crítico: -0.2008 | Perda Gerador: 6.3262
# [Época 098] [Lote 900/937] Perda Crítico: -0.3986 | Perda Gerador: 5.9597
# [Época 098] [Lote 936/937] Perda Crítico: -0.6783 | Perda Gerador: 10.3287
# [Época 099] [Lote 000/937] Perda Crítico: 0.5126 | Perda Gerador: 7.9671
# [Época 099] [Lote 100/937] Perda Crítico: -0.1224 | Perda Gerador: 8.2822
# [Época 099] [Lote 200/937] Perda Crítico: -0.3747 | Perda Gerador: 8.7705
# [Época 099] [Lote 300/937] Perda Crítico: 0.0315 | Perda Gerador: 2.4454
# [Época 099] [Lote 400/937] Perda Crítico: -0.7675 | Perda Gerador: -4.1051
# [Época 099] [Lote 500/937] Perda Crítico: 0.6499 | Perda Gerador: -2.3765
# [Época 099] [Lote 600/937] Perda Crítico: -0.2697 | Perda Gerador: 1.4250
# [Época 099] [Lote 700/937] Perda Crítico: 0.2472 | Perda Gerador: 6.5951
# [Época 099] [Lote 800/937] Perda Crítico: -2.3531 | Perda Gerador: 10.4840
# [Época 099] [Lote 900/937] Perda Crítico: 0.1006 | Perda Gerador: -4.6082
# [Época 099] [Lote 936/937] Perda Crítico: -0.0384 | Perda Gerador: -3.8981
# [Época 100] [Lote 000/937] Perda Crítico: 0.0410 | Perda Gerador: -2.6784
# [Época 100] [Lote 100/937] Perda Crítico: -0.6019 | Perda Gerador: 7.6643
# [Época 100] [Lote 200/937] Perda Crítico: -0.0639 | Perda Gerador: -1.2645
# [Época 100] [Lote 300/937] Perda Crítico: 0.0123 | Perda Gerador: 2.3721
# [Época 100] [Lote 400/937] Perda Crítico: -0.0932 | Perda Gerador: -0.1457
# [Época 100] [Lote 500/937] Perda Crítico: 0.6421 | Perda Gerador: -1.4612
# [Época 100] [Lote 600/937] Perda Crítico: 0.0441 | Perda Gerador: -0.2877
# [Época 100] [Lote 700/937] Perda Crítico: 0.0741 | Perda Gerador: -1.0293
# [Época 100] [Lote 800/937] Perda Crítico: 0.0212 | Perda Gerador: -1.5864
# [Época 100] [Lote 900/937] Perda Crítico: -0.1719 | Perda Gerador: 2.8947
# [Época 100] [Lote 936/937] Perda Crítico: 0.0125 | Perda Gerador: 0.3988
# Fim!

# %% [markdown]
# ## Resultados

# %%
# Define a função de gerar dados falsos de um vetores latentes aleatorios
def gerar_aleatorio(gerador, device, z_dim=z_dim, n_images=20):
    gerador.eval()                  # Coloca o modelo em modo de avaliação (desativa dropout, batchnorm, etc.)
    z = torch.randn((n_images, z_dim), device=device)
    # Desativa o cálculo de gradientes para economizar memória e acelerar a execução
    with torch.no_grad():
      dados_falsos = modelo_gerador(z).detach().cpu().numpy()
    return dados_falsos

# Função para plotar várias imagens em um grid
def plot_multiple_images(imagens, n_cols=7):
    n_cols = n_cols
    n_rows = (len(imagens) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows))
    for index, img in enumerate(imagens):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(img.reshape(28, 28), cmap="gray")
        plt.axis("off")
    plt.show()

# Gera um lote com imagens falsas
imagens = gerar_aleatorio(modelo_gerador, device, z_dim=z_dim, n_images=28)

# Chama a função para plotar as imagens
plot_multiple_images(imagens, n_cols=7)

# %%
z = torch.randn((1, z_dim), device=device)
dados_falsos = modelo_gerador(z).detach()
plt.figure()
plt.imshow(dados_falsos.detach().cpu().numpy().reshape(28,28))
plt.show()

# %% [markdown]
# ## Evolução das saídas do gerador para um vetor latente fixo durante o treinamento

# %%
# Lista com imagens
imagens = evolução_dado_falso

# Cria subplots (1 linha, -1 colunas)
fig, axes = plt.subplots(1, len(evolução_dado_falso), figsize=(15, 2))

# Itera por cada subplot e mostra a imagem
for ax, img in zip(axes, imagens):
    ax.imshow(img, cmap='gray')    # 1 = preto, 0 = branco
    ax.axis('off')                 # Remove ticks dos eixos

plt.subplots_adjust(wspace=0.1)    # ajusta o espacamento entre subplots

plt.show()

# %% [markdown]
# ## Interpolação no espaço latente

# %%
# Função que interpola entre dois vetores latentes e gera imagens correspondentes
def interpolar_espaco_latente(gerador, z_dim=100, steps=10, device='cpu'):

    # Gera dois vetores latentes aleatórios
    z1 = torch.randn((1, z_dim), device=device)
    z2 = torch.randn((1, z_dim), device=device)

    gerador.eval()  # Coloca o gerador em modo de avaliação

    alpha_valores = torch.linspace(0, 1, steps).to(device)  # Valores de interpolação entre 0 e 1
    imagens_interpoladas = []

    for alpha in alpha_valores:
        # Interpola linearmente entre z1 e z2: z_interp = (1 - alpha) * z1 + alpha * z2 , alpha em [0, 1]
        z_interp = (1 - alpha) * z1 + alpha * z2

        with torch.no_grad():  # Evita calcular gradientes
            imagem_gerada = gerador(z_interp.to(device)).cpu()

        # Remove dimensões extras e converte para numpy
        imagens_interpoladas.append(imagem_gerada.squeeze().numpy())

    return imagens_interpoladas

# %%
# Função para plotar uma lista de imagens em uma única linha
def plotar_imagens(imagens):
    fig, eixos = plt.subplots(1, len(imagens), figsize=(len(imagens), 1.5))
    for ax, img in zip(eixos, imagens):
        ax.imshow(img.reshape(28, 28), cmap='gray')  # Mostra a imagem em escala de cinza
        ax.axis('off')                               # Remove os eixos para visualização limpa
    plt.tight_layout()
    plt.show()

# %%
# Gera imagens interpoladas entre z1 e z2
imagens = interpolar_espaco_latente(modelo_gerador, z_dim=z_dim, steps=10, device=device)

# Plota as imagens lado a lado
plotar_imagens(imagens)

# %% [markdown]
# # Tarefa (em duplas)
#
# **Implementar uma WGAN condicional e treiná-la com o conjunto [*Fashion-MNIST*](https://docs.pytorch.org/vision/stable/generated/torchvision.datasets.FashionMNIST.html#torchvision.datasets.FashionMNIST)**
#
# Utilize o código acima como base e adapte-o para o seguinte problema:
#
# 1. Torne o **gerador condicional**: além do vetor de ruído `z`, ele deve receber o rótulo da classe. Represente o rótulo por um vetor *one-hot* de 10 posições e concatene-o ao ruído, de modo que a primeira camada passe a receber `z_dim + n_classes` entradas.
#
# 2. Torne o **crítico condicional**: ele deve avaliar o par (imagem, rótulo), e não apenas a imagem. Uma forma simples é expandir o rótulo em canais do tamanho da imagem e concatená-los à entrada, fazendo a primeira convolução receber `1 + n_classes` canais.
#
# 3. Treine o modelo mantendo o esquema WGAN do código base: `n_critic` passos do crítico para cada passo do gerador, *clipping* dos pesos do crítico e perdas `perda_critico = saída_falsos.mean() - saída_reais.mean()` e `perda_gerador = -saída_falsos.mean()`.
#
# 4. Registre e apresente as **curvas de perda** do gerador e do crítico ao longo das épocas (adapte a função `train_wgan` para acumular e retornar as perdas médias por época).
#
# 5. Gere uma **grade de amostras** com o modelo treinado, organizada com uma classe por linha (as 10 classes do *Fashion-MNIST*) e várias amostras por coluna, de modo que se possa verificar se o rótulo é de fato respeitado.
#
# 6. Faça a **interpolação no espaço latente**, para os três casos abaixo. Em cada um, plote as imagens intermediárias lado a lado:
#
#    a. `z` fixo e interpolação linear entre duas classes `[c1, c2]`;
#
#    b. classe `c` fixa e interpolação linear entre dois vetores de ruído `[z1, z2]`;
#
#    c. interpolação linear simultânea entre `[z1, z2]` e `[c1, c2]`.
#
# 7. Fixe o vetor de ruído `z` e **varie apenas o rótulo** entre as 10 classes, plotando as 10 imagens resultantes lado a lado.
#
# **Mantenha os hiperparâmetros do código base (`z_dim=100`, `batch_size=64`, `n_critic=5`, `clip_value=0.01`, `RMSprop` com `lr=1e-4` para as duas redes) e treine por 100 épocas.** Se alterar algum deles, registre e justifique a alteração no relatório.
#
# **Entregáveis:**
#
# Os entregáveis são **cumulativos ao longo da Unidade 1**. Ao final da unidade,
# você entregará **apenas dois arquivos**, reunindo todos os laboratórios:
#
# 1. **Notebook** (`.ipynb`) — um único notebook com o código de todos os
#    laboratórios da unidade, cada um em sua própria seção, na ordem em que foram
#    realizados.
#
#    O notebook deve **executar do início ao fim sem erros**, em um kernel novo,
#    com *Restart & Run All*. Antes de entregar, execute-o dessa forma e confirme
#    que todas as células rodam na ordem em que aparecem e que as saídas exibidas
#    correspondem a essa execução. Notebooks que não executarem por completo serão
#    penalizados.
#
# 2. **Relatório** (`.pdf`) — um único PDF, também organizado em seções, uma por
#    laboratório.
#
# Este laboratório corresponde à **Seção 3 — WGAN condicional**, que deve conter:
#
# - **Setup**: dados utilizados (conjunto, normalização aplicada e tamanho do
#   lote), arquiteturas do gerador e do crítico com a descrição explícita de
#   **como o rótulo foi injetado em cada rede**, e hiperparâmetros (otimizador,
#   taxas de aprendizado, dimensão do vetor de ruído, `n_critic`, `clip_value` e
#   número de épocas). Se alguma arquitetura ou hiperparâmetro do código base for
#   alterado, registre a alteração explicitamente e justifique.
# - **Resultados**:
#   - curvas de perda do gerador e do crítico ao longo das épocas;
#   - grade de amostras geradas com uma classe por linha;
#   - evolução das saídas do gerador para um vetor latente fixo ao longo do
#     treinamento, incluindo o início, o meio e o final;
#   - as três interpolações do item 6;
#   - as 10 imagens obtidas com `z` fixo e rótulo variável (item 7).
# - **Análise**: texto breve (5-10 linhas) discutindo os resultados obtidos.
#
# Nos próximos laboratórios da unidade, acrescente uma nova seção a cada arquivo,
# preservando as anteriores.
#
# O relatório **não** deve conter código.
#
# A entrega é **única por grupo**. Identifique os integrantes no início do
# notebook e na primeira página do relatório.
